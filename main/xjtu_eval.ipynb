# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torchvision.models import resnet18
from torchvision import transforms
from tqdm import tqdm
from torch import nn
from torch.utils.data import Dataset,TensorDataset,DataLoader,random_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from d2l import torch as d2l
import random
import os
import torch.nn.functional as F
from torch.autograd import grad
import torch.nn.init as init
d2l.use_svg_display()

import math

# %%
Batch_list=['Batch-1','Batch-2','Batch-3','Batch-4','Batch-5','Batch-6']
def choose_batch(Batch_name):
    Battery_list=[]
    dir='../source_data/XJTU_data/'+Batch_name
    for name in os.listdir(dir):
        Battery_list.append(name.strip('.mat'))
    source_data_path='../source_data/XJTU_data/'+Batch_name+'/'
    target_data_path='../data/XJTU_data/'+Batch_name+'/'+'all/'
    return Battery_list,source_data_path,target_data_path
Battery_list,source_data_path,target_data_path=choose_batch(Batch_list[0])
print(Battery_list)
def smooth_data(sequence, window_size):
    """数据平滑"""
    if window_size < 1:
        raise ValueError("窗口大小必须大于等于1")
    # 初始化平滑后的数据列表
    smoothed_sequence = []
    # 计算窗口内的平均值
    for i in range(len(sequence)):
        # 计算窗口的起始和结束索引
        start_index = max(0, i - window_size + 1)
        end_index = i + 1
        # 计算窗口内的数据平均值
        window_average = sum(sequence[start_index:end_index]) / (end_index - start_index)
        # 将平均值添加到平滑后的数据列表中
        smoothed_sequence.append(window_average)
    return smoothed_sequence
def add_row_index_to_array(arr):
    """
    在输入数组的每一行的第一个元素加上行号，并扩展数组维度。
    
    参数:
    arr (np.ndarray): 形状为 (n, 6) 的输入数组。
    
    返回:
    np.ndarray: 形状为 (n, 7) 的数组。
    """
    # 检查输入数组形状是否为 (n, 6)
    if arr.shape[1] != 10:
        raise ValueError("输入数组必须是形状为 (n, 10) 的数组。")

    # 创建一个新数组，其形状为 (n, 7)，初始化为输入数组
    new_arr = np.zeros((arr.shape[0], 11))
    new_arr[:, 1:] = arr  # 将输入数组的数据复制到新数组的后面六个列
    # 在新数组的每一行的第一个元素加上行号
    new_arr[:, 0] = np.arange(arr.shape[0])
    return new_arr
def make_sequences(text, window_size):
    """用容量作为文本序列text,window是窗口的大小"""
    x, y = [],[]
    for i in range(len(text) - window_size):
        sequence = text[i:i+window_size]
        target = text[i+window_size]

        x.append(sequence)
        y.append(target)
    return np.array(x), np.array(y)
def drop_outlier(array,count,bins):
    """离群值提取--用3sigma方法"""
    index = []
    range_n = np.arange(1,count,bins)
    for i in range_n[:-1]:
        array_lim = array[i:i+bins]
        sigma = np.std(array_lim)
        mean = np.mean(array_lim)
        th_max,th_min = mean + sigma*2, mean - sigma*2
        idx = np.where((array_lim < th_max) & (array_lim > th_min))
        idx = idx[0] + i
        index.extend(list(idx))
    return np.array(index)
def clean_data(array_figs,array_labels):
    index_keep=drop_outlier(array_labels,len(array_labels),35)
    array_figs,array_labels=array_figs[index_keep],array_labels[index_keep]
    array_figs,array_labels=array_figs[drop_outlier(array_labels,len(array_labels),10)],array_labels[drop_outlier(array_labels,len(array_labels),10)]
    return array_figs,array_labels
data_root=target_data_path
plt.figure(figsize=(5, 4))
for name in Battery_list:
    path=data_root+name+'.npz'
    arrays=np.load(path)
    features,SOHs=clean_data(arrays['array1'],arrays['array2'])
    plt.plot(SOHs/2.0)
    # """抛弃异常值处理"""
    # index_keep=drop_outlier(SOHs,len(SOHs),35)
    # plt.plot(SOHs[index_keep][drop_outlier(SOHs[index_keep],len(SOHs[index_keep]),10)])
    # plt.plot(process_sequence(SOHs,1))
    plt.yticks([0.8,0.85,0.9,0.95,1],fontsize=14)
    plt.xticks([0,100,200,300],fontsize=14)
    plt.xlabel('Cycle', fontsize=16)
    plt.ylabel('SOH',fontsize=16)
    # print(features[1][0])
# plt.show()
# Out:
# ['2C_battery-1', '2C_battery-2', '2C_battery-3', '2C_battery-4', '2C_battery-5', '2C_battery-6', '2C_battery-7', '2C_battery-8']

# %%
def setup_seed(seed):
    """set random seed"""
    np.random.seed(seed)  # Numpy module.
    random.seed(seed)  # Python random module.
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.manual_seed(seed) 
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True

def evaluation(y_test, y_predict):
    mse = mean_squared_error(y_test, y_predict)
    rmse = sqrt(mean_squared_error(y_test, y_predict))
    return rmse
def get_data():
    """获取训练集，测试集，验证集"""
    train_list = Battery_list
    train_data=[]
    for b_n in train_list:
        path=data_root+b_n+'.npz'
        arrays = np.load(path)
        a,b=clean_data(arrays['array1'],arrays['array2'])
        a=add_row_index_to_array(a)
        train_data.append([a,b])
    train_features=np.concatenate((train_data[0][0],train_data[1][0],train_data[2][0],train_data[3][0],train_data[4][0]),axis=0)
    train_labls=np.concatenate((train_data[0][1],train_data[1][1],train_data[2][1],train_data[3][1],train_data[4][1]),axis=0)
    train_valid_features=torch.from_numpy(train_features).float()
    train_valid_labels=torch.from_numpy(train_labls).float()
    dataset=TensorDataset(train_valid_features,train_valid_labels)
    # 确定训练集和验证集的大小
    train_size = int(0.2 * len(dataset))  # 80%的训练集
    val_size = len(dataset) - train_size   # 剩余的20%作为验证集
    # 随机分割数据集
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    # 创建DataLoader
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_5_data,test_6_data,test_7_data=[np.concatenate((train_data[5][0],train_data[0][0],train_data[1][0],train_data[2][0]),axis=0),np.concatenate((train_data[5][1],train_data[0][1],train_data[1][1],train_data[2][1]),axis=0)],[train_data[6][0],train_data[6][1]],[train_data[7][0],train_data[7][1]]
    return train_loader, val_loader, test_5_data,test_6_data,test_7_data

a,b,c,d,e=get_data()
print(d,e)
for x,y in b:
    print(x.shape)
# Out:
# [array([[0.00000000e+00, 8.10116599e-01, 2.05529220e-01, ...,
#         7.50713571e-01, 1.00000000e+00, 5.46999916e-03],
#        [1.00000000e+00, 8.10116599e-01, 2.05529220e-01, ...,
#         7.50713571e-01, 1.00000000e+00, 5.46999916e-03],
#        [2.00000000e+00, 8.10116599e-01, 2.05529220e-01, ...,
#         7.50713571e-01, 1.00000000e+00, 5.46999916e-03],
#        ...,
#        [2.60000000e+02, 4.56911290e-01, 8.30281021e-01, ...,
#         7.14768346e-01, 1.10282954e-01, 5.22973996e-01],
#        [2.61000000e+02, 4.64166178e-01, 7.90670802e-01, ...,
#         7.24159078e-01, 1.04209800e-01, 5.26676765e-01],
#        [2.62000000e+02, 4.68563913e-01, 7.76807393e-01, ...,
#         7.15860345e-01, 9.82746722e-02, 5.29832534e-01]]), array([1.967, 1.966, 1.966, 1.965, 1.964, 1.967, 1.969, 1.968, 1.968,
#        1.967, 1.966, 1.966, 1.965, 1.965, 1.965, 1.964, 1.963, 1.963,
#        1.964, 1.966, 1.963, 1.962, 1.96 , 1.959, 1.96 , 1.958, 1.957,
#        1.957, 1.957, 1.958, 1.956, 1.954, 1.953, 1.952, 1.951, 1.95 ,
#        1.953, 1.955, 1.954, 1.954, 1.953, 1.952, 1.951, 1.95 , 1.95 ,
#        1.949, 1.949, 1.949, 1.952, 1.952, 1.951, 1.951, 1.951, 1.95 ,
#        1.95 , 1.949, 1.948, 1.947, 1.947, 1.946, 1.946, 1.947, 1.946,
#        1.947, 1.946, 1.945, 1.944, 1.942, 1.941, 1.944, 1.946, 1.945,
#        1.945, 1.942, 1.94 , 1.939, 1.939, 1.937, 1.942, 1.946, 1.947,
#        1.946, 1.944, 1.943, 1.942, 1.941, 1.94 , 1.939, 1.939, 1.938,
#        1.938, 1.939, 1.939, 1.938, 1.938, 1.936, 1.935, 1.934, 1.933,
#        1.933, 1.932, 1.932, 1.931, 1.93 , 1.93 , 1.929, 1.929, 1.929,
#        1.928, 1.927, 1.926, 1.926, 1.925, 1.925, 1.924, 1.924, 1.923,
#        1.923, 1.922, 1.922, 1.92 , 1.919, 1.918, 1.917, 1.916, 1.916,
#        1.915, 1.914, 1.913, 1.913, 1.912, 1.911, 1.91 , 1.909, 1.909,
#        1.908, 1.907, 1.906, 1.904, 1.903, 1.902, 1.901, 1.896, 1.895,
#        1.894, 1.892, 1.89 , 1.889, 1.888, 1.886, 1.884, 1.882, 1.881,
#        1.88 , 1.879, 1.877, 1.876, 1.875, 1.873, 1.873, 1.871, 1.87 ,
#        1.87 , 1.869, 1.857, 1.856, 1.852, 1.85 , 1.849, 1.848, 1.848,
#        1.847, 1.846, 1.845, 1.845, 1.845, 1.843, 1.841, 1.84 , 1.838,
#        1.836, 1.837, 1.838, 1.836, 1.834, 1.831, 1.829, 1.827, 1.824,
#        1.822, 1.82 , 1.82 , 1.824, 1.825, 1.822, 1.819, 1.818, 1.819,
#        1.818, 1.813, 1.81 , 1.808, 1.806, 1.804, 1.808, 1.808, 1.808,
#        1.804, 1.804, 1.801, 1.799, 1.797, 1.796, 1.794, 1.789, 1.789,
#        1.784, 1.78 , 1.775, 1.772, 1.77 , 1.768, 1.765, 1.763, 1.761,
#        1.759, 1.757, 1.755, 1.752, 1.75 , 1.749, 1.743, 1.74 , 1.737,
#        1.735, 1.732, 1.729, 1.726, 1.725, 1.724, 1.722, 1.722, 1.72 ,
#        1.715, 1.712, 1.71 , 1.708, 1.705, 1.705, 1.705, 1.702, 1.7  ,
#        1.689, 1.684, 1.682, 1.685, 1.685, 1.682, 1.665, 1.664, 1.661,
#        1.659, 1.66 ])] [array([[0.00000000e+00, 9.25147322e-01, 0.00000000e+00, ...,
#         8.32391590e-01, 1.00000000e+00, 1.68692921e-03],
#        [1.00000000e+00, 9.25147322e-01, 0.00000000e+00, ...,
#         8.32391590e-01, 1.00000000e+00, 1.68692921e-03],
#        [2.00000000e+00, 9.25147322e-01, 0.00000000e+00, ...,
#         8.32391590e-01, 1.00000000e+00, 1.68692921e-03],
#        ...,
#        [2.91000000e+02, 1.43563972e-01, 7.71991078e-01, ...,
#         5.33112647e-01, 3.50708293e-02, 8.83834565e-01],
#        [2.92000000e+02, 9.17911921e-02, 7.60753962e-01, ...,
#         5.27188994e-01, 2.64062715e-02, 8.91396661e-01],
#        [2.93000000e+02, 6.49620888e-02, 7.00490447e-01, ...,
#         5.18324240e-01, 1.74666483e-02, 8.99889477e-01]]), array([1.953, 1.952, 1.951, 1.951, 1.951, 1.95 , 1.95 , 1.955, 1.956,
#        1.955, 1.955, 1.954, 1.954, 1.954, 1.954, 1.954, 1.953, 1.952,
#        1.954, 1.953, 1.952, 1.951, 1.951, 1.951, 1.95 , 1.95 , 1.949,
#        1.95 , 1.95 , 1.95 , 1.95 , 1.951, 1.951, 1.949, 1.95 , 1.949,
#        1.947, 1.946, 1.946, 1.946, 1.946, 1.946, 1.948, 1.95 , 1.95 ,
#        1.949, 1.949, 1.948, 1.948, 1.947, 1.946, 1.946, 1.946, 1.945,
#        1.946, 1.946, 1.947, 1.947, 1.946, 1.945, 1.945, 1.945, 1.944,
#        1.943, 1.944, 1.947, 1.947, 1.946, 1.946, 1.943, 1.943, 1.941,
#        1.941, 1.94 , 1.941, 1.946, 1.949, 1.947, 1.946, 1.945, 1.944,
#        1.943, 1.942, 1.942, 1.941, 1.94 , 1.941, 1.942, 1.941, 1.941,
#        1.939, 1.938, 1.937, 1.937, 1.936, 1.936, 1.935, 1.934, 1.934,
#        1.933, 1.933, 1.932, 1.932, 1.931, 1.931, 1.93 , 1.93 , 1.929,
#        1.928, 1.928, 1.927, 1.927, 1.925, 1.925, 1.924, 1.923, 1.922,
#        1.921, 1.919, 1.919, 1.918, 1.918, 1.916, 1.915, 1.914, 1.914,
#        1.913, 1.913, 1.912, 1.911, 1.91 , 1.909, 1.908, 1.905, 1.904,
#        1.903, 1.901, 1.9  , 1.898, 1.897, 1.895, 1.894, 1.892, 1.89 ,
#        1.89 , 1.888, 1.886, 1.884, 1.882, 1.882, 1.88 , 1.879, 1.878,
#        1.877, 1.875, 1.874, 1.873, 1.872, 1.872, 1.871, 1.869, 1.869,
#        1.868, 1.865, 1.859, 1.858, 1.857, 1.856, 1.855, 1.854, 1.852,
#        1.852, 1.851, 1.849, 1.848, 1.847, 1.848, 1.847, 1.845, 1.844,
#        1.842, 1.841, 1.841, 1.842, 1.84 , 1.835, 1.83 , 1.828, 1.827,
#        1.828, 1.832, 1.832, 1.829, 1.827, 1.826, 1.827, 1.821, 1.819,
#        1.817, 1.815, 1.814, 1.819, 1.82 , 1.819, 1.817, 1.816, 1.814,
#        1.813, 1.812, 1.811, 1.81 , 1.809, 1.808, 1.809, 1.809, 1.805,
#        1.805, 1.803, 1.799, 1.798, 1.797, 1.796, 1.793, 1.791, 1.791,
#        1.79 , 1.789, 1.787, 1.786, 1.787, 1.787, 1.787, 1.782, 1.776,
#        1.776, 1.776, 1.776, 1.774, 1.774, 1.769, 1.767, 1.765, 1.765,
#        1.766, 1.763, 1.756, 1.755, 1.753, 1.752, 1.75 , 1.749, 1.753,
#        1.754, 1.752, 1.736, 1.734, 1.733, 1.733, 1.734, 1.735, 1.732,
#        1.731, 1.728, 1.727, 1.722, 1.719, 1.715, 1.712, 1.71 , 1.707,
#        1.707, 1.707, 1.705, 1.703, 1.698, 1.695, 1.691, 1.687, 1.684,
#        1.68 , 1.676, 1.673, 1.671, 1.673, 1.667, 1.663, 1.659, 1.658,
#        1.651, 1.647, 1.644, 1.64 , 1.637, 1.636])]
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([32, 11])
# torch.Size([7, 11])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, input_dim=11, output_dim=12, num_heads=4, head_dim=24, dropout=0):
        """用多头注意力进行解码"""
        """
        多头注意力模块。
        :param input_dim: 输入特征维度
        :param output_dim: 输出特征维度
        :param num_heads: 注意力头的数量
        :param head_dim: 每个注意力头的维度
        :param dropout: Dropout 概率
        """
        super(MultiHeadAttention, self).__init__()
        self.input_dim = input_dim-1
        self.output_dim = output_dim-1
        self.num_heads = num_heads
        self.head_dim = head_dim
        self.dropout = dropout
        # 线性变换层，将输入映射到 Q, K, V
        self.query = nn.Linear(input_dim-1, num_heads * head_dim)
        self.key = nn.Linear(input_dim-1, num_heads * head_dim)
        self.value = nn.Linear(input_dim-1, num_heads * head_dim)
        # 输出线性层
        self.fc_out = nn.Linear(num_heads * head_dim, output_dim-1)
        # Dropout 层
        self.dropout_layer = nn.Dropout(dropout)
    def forward(self, x):
        """
        前向传播。
        :param x: 输入张量，形状为 (batch_size, input_dim)
        :return: 输出张量，形状为 (batch_size, output_dim)
        """
        batch_size = x.size(0)
        x_t=x[:,0].unsqueeze(1)
        x=x[:,1:]
        # 线性变换，得到 Q, K, V
        Q = self.query(x).view(batch_size, -1, self.num_heads, self.head_dim).transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        K = self.key(x).view(batch_size, -1, self.num_heads, self.head_dim).transpose(1, 2)    # (batch_size, num_heads, seq_len, head_dim)
        V = self.value(x).view(batch_size, -1, self.num_heads, self.head_dim).transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        # 计算注意力分数
        scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(torch.tensor(self.head_dim, dtype=torch.float32))  # (batch_size, num_heads, seq_len, seq_len)
        attention_weights = F.softmax(scores, dim=-1)  # (batch_size, num_heads, seq_len, seq_len)
        attention_weights = self.dropout_layer(attention_weights)
        # 计算加权和
        attention_output = torch.matmul(attention_weights, V)  # (batch_size, num_heads, seq_len, head_dim)
        # 拼接多头输出
        attention_output = attention_output.transpose(1, 2).contiguous().view(batch_size, -1, self.num_heads * self.head_dim)  # (batch_size, seq_len, num_heads * head_dim)
        # 通过线性层映射到输出维度
        output = self.fc_out(attention_output)  # (batch_size, seq_len, output_dim)
        output=torch.cat((x_t,output.squeeze(1)),dim=-1)
        return output  # (batch_size, output_dim)
"""--------------------------------------------------------多物理场混合专家模型-------------------------------------------------------"""
class MixtureOfExperts(nn.Module):
    def __init__(self, input_dim, num_experts, expert_hidden_dim):
        super(MixtureOfExperts, self).__init__()
        self.num_experts = num_experts
        # 专家网络
        self.experts = nn.ModuleList([
            nn.Sequential(
                nn.Linear(input_dim, 2*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(2*expert_hidden_dim, 4*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(4*expert_hidden_dim, 8*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(8*expert_hidden_dim, 16*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(16*expert_hidden_dim, 32*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(32*expert_hidden_dim,64*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(64*expert_hidden_dim,32*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(32*expert_hidden_dim,16*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(16*expert_hidden_dim, 8*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(8*expert_hidden_dim, 4*expert_hidden_dim),
                nn.ReLU(),
                nn.Linear(4*expert_hidden_dim,expert_hidden_dim ),
            )
            for _ in range(num_experts)
        ])
        # 门控网络
        self.gating_network = nn.Linear(input_dim, num_experts)
        # 输出层
        self.output_layer = nn.Linear(expert_hidden_dim, 1)
    def initialize_weights(self):
        nn.init.xavier_uniform_(self.gating_network.weight)
        nn.init.xavier_uniform_(self.output_layer.weight)
    def forward(self, x):
        # 计算所有专家的输出
        expert_outputs = torch.stack([expert(x) for expert in self.experts], dim=1)
        #shape(batch_size,num_expert,expert_hidden_dim)
        # 计算门控网络的输出并应用softmax得到权重
        gate_works=torch.exp(self.gating_network(x)/500)
        gating_outputs = F.softmax(gate_works, dim=1)
        # 将门控网络的输出（权重）与专家网络的输出相乘并求和
        combined_output = torch.sum(expert_outputs * gating_outputs.unsqueeze(-1), dim=1)
        # 通过输出层得到最终输出
        final_output = self.output_layer(combined_output)
        return final_output,expert_outputs      #返回总输出和每个专家输出
    
class PINN_MOE(nn.Module):
    def __init__(self,input_dim=11, output_dim=12, num_heads=4, head_dim=24, dropout=0,expert_input_dim=12, num_experts=3,expert_hidden_dim=2):
        super(PINN_MOE, self).__init__()
        self.Decoupling=MultiHeadAttention(input_dim, output_dim, num_heads, head_dim, dropout)
        self.multi_physics=MixtureOfExperts(expert_input_dim, num_experts,expert_hidden_dim)
        self.physics=nn.Sequential(
            nn.Linear(6, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
        )
        # self.electricity=nn.Sequential(nn.Linear(expert_hidden_dim, 2*expert_hidden_dim),nn.ReLU(),nn.Linear(2*expert_hidden_dim,expert_hidden_dim),nn.ReLU(),nn.Linear(expert_hidden_dim,2))
        # self.heat=nn.Sequential(nn.Linear(expert_hidden_dim, 2*expert_hidden_dim),nn.ReLU(),nn.Linear(2*expert_hidden_dim,expert_hidden_dim),nn.ReLU(),nn.Linear(expert_hidden_dim,2))
        # self.mechine=nn.Sequential(nn.Linear(expert_hidden_dim, 2*expert_hidden_dim),nn.ReLU(),nn.Linear(2*expert_hidden_dim,expert_hidden_dim),nn.ReLU(),nn.Linear(expert_hidden_dim,2))
        self.parameter_heat=nn.Parameter(torch.tensor(1, dtype=torch.float32))
        self.parameter_electricity1=nn.Parameter(torch.tensor(1, dtype=torch.float32))
        self.parameter_electricity2=nn.Parameter(torch.tensor(1, dtype=torch.float32))
    def  initialize_weights(self):
        nn.init.xavier_uniform_(self.Decoupling.parameters)
        nn.init.xavier_uniform_(self.multi_physics.parameters)
        # nn.init.xavier_uniform_(self.heat.parameters)
        # nn.init.xavier_uniform_(self.mechine.parameters)
        # nn.init.xavier_uniform_(self.electricity.parameters)
        nn.init.xavier_uniform_(self.physics.parameters)
        nn.init.xavier_uniform_(self.parameter_heat)
        nn.init.xavier_uniform_(self.parameter_electricity1)
        nn.init.xavier_uniform_(self.parameter_electricity2)
    def forward(self, tx):
        tx.requires_grad_(True)
        # 解耦输入
        t_x = self.Decoupling(tx)
        def safe_grad(y, x_):
            # 如果 y 本身就不在计算图里（不需要梯度），直接返回 0（但要保持和 x_ 有依赖，方便二阶导）
            if (not torch.is_tensor(y)) or (not y.requires_grad):
                return x_ * 0.0

            g = grad(y, x_, create_graph=True, only_inputs=True, allow_unused=True)[0]
            if g is None:
                # 关键：不能用 zeros_like(x_)，要用 x_*0，让它仍然“挂在”x_上，从而有 grad_fn
                return x_ * 0.0
            return g

        t=t_x[:,0:1]
        x=t_x[:,1:]
        # 预测物理量
        s_pred,experts = self.multi_physics(torch.cat((t,x),dim=1))
        # 计算 s_pred 对 t 和 x 的偏导数
        """综合损失"""
        s_t = grad(s_pred.sum(),t,create_graph=True,only_inputs=True,allow_unused=True)[0]
        s_x = grad(s_pred.sum(),x,create_graph=True,only_inputs=True,allow_unused=True)[0]
        """热效应损失"""
        T_Q = experts[:, 0:1, :].squeeze(1)
        T = T_Q[:, 0:1]
        Q = T_Q[:, 1:2]

        # 选空间坐标（默认用 x 的第 1 维做空间坐标）
        x_phys = x[:, 0:1]

        # 梯度（用 safe_grad 防止 None）
        T_t  = safe_grad(T.sum(), t)
        T_x  = safe_grad(T.sum(), x_phys)
        T_xx = safe_grad(T_x.sum(), x_phys)

        rho_cp = 1.0
        k = self.parameter_heat

        res_heat = rho_cp * T_t - k * T_xx + Q

        loss_heat = torch.mean(res_heat ** 2, dim=1).unsqueeze(1)

        """电化学效应损失"""
        phi_c=experts[:,1:2,:].squeeze(1)
        phi=phi_c[:,0:1]
        c=phi_c[:,1:2]
        phi_t=grad(phi.sum(),t,create_graph=True,only_inputs=True,allow_unused=True)[0]
        phi_x=grad(phi.sum(),x,create_graph=True,only_inputs=True,allow_unused=True)[0]
        c_x=grad(c.sum(),x,create_graph=True,only_inputs=True,allow_unused=True)[0]
        c_t=grad(c.sum(),t,create_graph=True,only_inputs=True,allow_unused=True)[0]
        phi_laplace=grad(phi_x.sum(),x,create_graph=True,only_inputs=True,allow_unused=True)[0]
        c_laplace=grad(c_x.sum(),x,create_graph=True,only_inputs=True,allow_unused=True)[0]
        loss_electricity=torch.mean((c_t -self.parameter_electricity1 * c_laplace -self.parameter_electricity2) ** 2,dim=1).unsqueeze(1)+torch.mean(phi_laplace** 2,dim=1).unsqueeze(1)
        """机械应力损失"""
        sigma_f = experts[:, 2:3, :].squeeze(1)
        sigma = sigma_f[:, 0:1]
        f = sigma_f[:, 1:2]

        # 选空间坐标（默认用 x 的第 1 维做空间坐标）
        x_phys = x[:, 0:1]

        # 1D div(sigma) = dσ/dx
        sigma_x = safe_grad(sigma.sum(), x_phys)

        res_mech = sigma_x + f
        loss_mechine = torch.mean(res_mech ** 2, dim=1).unsqueeze(1)


        # 打印 s_t 和 s_x，确保它们不为 None
        # 计算物理约束 F
        F_input = torch.cat([phi,c,T,Q,sigma,f], dim=1)
        soh = self.physics(F_input)
        # 计算残差 f
        loss_all = 1*loss_electricity+1*loss_heat+1*loss_mechine
        return soh, loss_all,[phi,c,T,Q,sigma,f]

# %%
def train(lr=0.005,epochs=200, weight_decay=1e-5, seed=0, metric='rmse', device='cpu'):
    """function for train"""
    setup_seed(seed)
    print("training seed "+str(seed)+':\n')
    train_loader, val_loader, test_35_data, test_36_data, test_37_data=get_data()
    test_data=[test_35_data, test_36_data, test_37_data]
    model = PINN_MOE()
    model=model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.MSELoss()
    len_dataloader = len(train_loader)
    test_results=[]
    lists=[]
    """早停止获取最佳模型"""
    val_mse=10
    train_loss=10
    for epoch in range(epochs):
        loss_epoch=0
        for X,y in train_loader:
            X,y = X.to(device), y.to(device)
            y_pred,f,_= model(X)
            f_target = torch.zeros_like(f)
            y_pred = y_pred.squeeze(1)
            loss = criterion(y_pred,y)+0.3*criterion(f,f_target)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_epoch += loss
        if (epoch+1)%5==0 and epoch!=0:
            print('Epoch:',epoch+1,'Train_RMSELoss:',loss_epoch/len_dataloader,'\n')
            train_loss=loss_epoch/len_dataloader
        if (epoch+1)%5==0 and epoch!=0:
            val_loss=0
            for val_x,val_y in val_loader:
                val_x,val_y=val_x.to(device),val_y.to(device)
                pre,_,_=model(val_x)
                val_loss+=criterion(pre.squeeze(1),val_y).detach()    
            print('Epoch:',epoch+1,'valid_RMSELoss:',val_loss/len(val_loader),'\n')
            val_mse=val_loss/len(val_loader)
                
        if (val_mse<7e-4 and train_loss<=2e-4) or (epoch+1)==epochs:
            model=model.cpu()
            # torch.save(model.state_dict(), '../pretrained/xjtu_model.pth')
            for name in test_data:
                X=torch.from_numpy(name[0]).float()
                y=name[1]
                y_pred,_,list=model(X)
                for i in range(len(list)):
                    list[i]=list[i].detach().cpu().numpy()
                lists.append(list)
                y_pred= y_pred.squeeze(0).detach().numpy()
                test_results.append([y,y_pred])
            break
    return test_results,lists

# %% [markdown]
# ## 多随机种子训练

# %%
tests=[]
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
for i in range(5):
    test_result,_=train(seed=i,device=device)
    tests.append(test_result)
# Out:
# training seed 0:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1420, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0051, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0610, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0314, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0182, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0113, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(9.9325e-05, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(9.8251e-05, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(7.3864e-05, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(6.2988e-05, device='cuda:0')
#
# training seed 1:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1448, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0061, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0602, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0310, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0174, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0106, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(8.6299e-05, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(9.8956e-05, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(8.4759e-05, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(7.6109e-05, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(6.8865e-05, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(8.0462e-05, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(5.5495e-05, device='cuda:0')
#
# training seed 2:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1515, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0097, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0613, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0318, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0182, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0114, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(8.2353e-05, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(9.7941e-05, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(9.8598e-05, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(6.7712e-05, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(6.1442e-05, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(7.1058e-05, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(7.7129e-05, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(6.9482e-05, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(4.6097e-05, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(6.9313e-05, device='cuda:0')
#
# training seed 3:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1703, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0109, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0601, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0311, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0180, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0110, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0075, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(9.8477e-05, device='cuda:0')
#
# training seed 4:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1393, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0032, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0608, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0014, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0313, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0177, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0110, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0072, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(8.3637e-05, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(6.6165e-05, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(7.6249e-05, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(8.4265e-05, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(8.4075e-05, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(5.8324e-05, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0001, device='cuda:0')

# %%
def calculate_mae(actual, predicted):
    """
    计算两个序列的MAE（平均绝对误差）
    
    参数:
    actual (list or numpy array): 实际值序列
    predicted (list or numpy array): 预测值序列
    
    返回:
    float: MAE值
    """
    # 确保输入序列长度一致
    if len(actual) != len(predicted):
        raise ValueError("实际值序列和预测值序列长度必须一致")
    
    # 计算绝对误差
    absolute_errors = [abs(a - p) for a, p in zip(actual, predicted)]
    
    # 计算平均绝对误差
    mae = sum(absolute_errors) / len(actual)
    
    return mae
def mape(sequence_true, sequence_pred):
    """
    计算两个序列的MAPE（Mean Absolute Percentage Error）

    参数:
    sequence_true: 实际值序列
    sequence_pred: 预测值序列

    返回:
    mape: 平均绝对百分比误差
    """
    if len(sequence_true) != len(sequence_pred):
        raise ValueError("两个序列的长度必须相同")

    # 计算绝对百分比误差
    ape = [abs((true - pred) / true) for true, pred in zip(sequence_true, sequence_pred) if true != 0]

    # 计算平均绝对百分比误差
    mape = sum(ape) / len(ape)

    return mape

# 示例使用
sequence_true = [100, 200, 300, 400, 500]
sequence_pred = [90, 210, 310, 380, 480]
print("MAPE:", mape(sequence_true, sequence_pred))
def r_squared(y_true, y_pred):
    """
    计算两个序列的R方（R-squared）

    参数:
    y_true: 实际值序列
    y_pred: 预测值序列

    返回:
    r2: R方值
    """
    # 计算实际值的平均值
    y_mean = sum(y_true) / len(y_true)
    
    # 计算总平方和（Total Sum of Squares, TSS）
    ss_total = sum((y_true - y_mean) ** 2)
    
    # 计算回归平方和（Regression Sum of Squares, RSS）
    ss_residual = sum((y_true - y_pred) ** 2)
    
    # 计算R方
    r2 = 1 - (ss_residual / ss_total)
    
    return r2
# Out:
# MAPE: 0.05466666666666666

# %%
rmse_all=[]
mae_all=[]
mape_all=[]
r2=[]
num=0
test_csv_p=[]
real_csv_p=[]
for i in range(4):
    for j in range(len(tests[0])):
        real,pred=tests[i][j][0],tests[i][j][1].reshape(-1)
        rmse=evaluation(real,pred)
        if rmse>=0.00:
            rmse_all.append(rmse)
            for pre,rea in zip(pred,real):
                test_csv_p.append(pre)
                real_csv_p.append(rea)
        mae_all.append(calculate_mae(real,pred))
        mape_all.append(mape(real,pred))
        r2.append(r_squared(real,pred))
        num+=1
print("RMSE:",rmse_all)
print("test:",test_csv_p)
print('real:',real_csv_p)
len(test_csv_p)
# Out:
# RMSE: [0.0074309862540755806, 0.010523262584621438, 0.01782137096997329, 0.007559004121487207, 0.0056416653353052095, 0.014579401369056038, 0.008689706063397317, 0.014396722490975143, 0.018960467713160664, 0.008830701342206404, 0.010616316621645748, 0.012490313149762369]
# test: [1.9526914, 1.9534259, 1.9540592, 1.9546174, 1.9551755, 1.955734, 1.9562923, 1.9568506, 1.957855, 1.9588667, 1.9603568, 1.9611994, 1.9612644, 1.9611124, 1.9603723, 1.9597584, 1.9591509, 1.9590107, 1.9591421, 1.958197, 1.9580177, 1.9579006, 1.9573466, 1.9568226, 1.9561, 1.9551533, 1.9543731, 1.9542207, 1.9536879, 1.9526683, 1.9515294, 1.9513494, 1.9511358, 1.9504482, 1.9507027, 1.9505483, 1.9501466, 1.9502609, 1.9499675, 1.949494, 1.949387, 1.9492486, 1.9494506, 1.9497726, 1.9499813, 1.9498076, 1.950078, 1.9503607, 1.9502687, 1.9501256, 1.9502906, 1.9499437, 1.9500104, 1.9496812, 1.9498638, 1.949205, 1.9488906, 1.9483709, 1.9478915, 1.9476733, 1.9474741, 1.9465543, 1.9461042, 1.9448483, 1.9444685, 1.9438864, 1.9434273, 1.9429163, 1.9428434, 1.9434352, 1.9434395, 1.9428967, 1.9420166, 1.9418449, 1.9411086, 1.9404938, 1.9411606, 1.9415163, 1.9416903, 1.9416517, 1.9414772, 1.9406182, 1.9401075, 1.9394854, 1.9388032, 1.938528, 1.9381934, 1.9379133, 1.93819, 1.9376383, 1.9371103, 1.9369491, 1.9362636, 1.9352258, 1.9340266, 1.9333173, 1.9323169, 1.9322977, 1.9319253, 1.9309388, 1.9311152, 1.9308894, 1.9301325, 1.9296352, 1.9296936, 1.9290965, 1.9280353, 1.9273306, 1.9269093, 1.9267867, 1.9262869, 1.925346, 1.9246721, 1.9239125, 1.9234071, 1.9226947, 1.9215013, 1.9214505, 1.9203755, 1.9197276, 1.9192895, 1.9183805, 1.9169184, 1.9157048, 1.9148499, 1.9132365, 1.9119686, 1.9114884, 1.9110427, 1.9100654, 1.9094576, 1.908367, 1.9068035, 1.9059623, 1.9044262, 1.9039214, 1.9024951, 1.9013016, 1.9001385, 1.8991114, 1.8991407, 1.8974551, 1.8964256, 1.8946952, 1.8927175, 1.8912748, 1.8891655, 1.8873597, 1.8864566, 1.8850639, 1.8839656, 1.8833523, 1.8815175, 1.8791993, 1.8767964, 1.8717047, 1.8698725, 1.8693675, 1.8649349, 1.8647565, 1.8622786, 1.8598714, 1.8581799, 1.8570915, 1.856036, 1.8549407, 1.8539497, 1.8525733, 1.8532671, 1.8517145, 1.8499233, 1.8475603, 1.8467362, 1.8461406, 1.8447831, 1.8408246, 1.8403773, 1.8371512, 1.8374244, 1.8357874, 1.8355721, 1.8348455, 1.8335257, 1.8318801, 1.8318454, 1.8294928, 1.8274748, 1.8256434, 1.8248056, 1.8241915, 1.8229707, 1.8231592, 1.8227513, 1.8203517, 1.8206643, 1.8189703, 1.8153253, 1.8140103, 1.8119594, 1.8118993, 1.808058, 1.8065985, 1.805659, 1.8044343, 1.8051457, 1.8044063, 1.8030561, 1.8022101, 1.8025393, 1.8036091, 1.8017148, 1.8006998, 1.8009826, 1.8006976, 1.8008173, 1.8002039, 1.7976644, 1.7943267, 1.7912769, 1.789766, 1.786965, 1.7872766, 1.7891234, 1.787104, 1.7862945, 1.7840184, 1.7808855, 1.7763866, 1.7722152, 1.7723598, 1.7689544, 1.7615759, 1.7567061, 1.7566844, 1.7571757, 1.7558982, 1.7534078, 1.7536354, 1.7504252, 1.7459797, 1.7404877, 1.737677, 1.7345186, 1.7302682, 1.7266546, 1.7239943, 1.7163662, 1.712178, 1.7111874, 1.7086798, 1.707222, 1.7046996, 1.7019943, 1.6987308, 1.6956025, 1.6915876, 1.6884124, 1.685054, 1.6838263, 1.6800183, 1.6775843, 1.6788888, 1.6786464, 1.6770868, 1.6761886, 1.6746943, 1.9541897, 1.9549228, 1.9555291, 1.9560875, 1.9566458, 1.957204, 1.9577624, 1.9583207, 1.9589683, 1.9595639, 1.9599758, 1.9608693, 1.9608847, 1.9608101, 1.9609503, 1.9614679, 1.9611255, 1.960545, 1.9599077, 1.9599463, 1.957741, 1.9572306, 1.9574169, 1.9564891, 1.9565872, 1.9566649, 1.9561967, 1.9556977, 1.9548514, 1.953704, 1.9528675, 1.9525894, 1.952124, 1.9521165, 1.9516101, 1.9518517, 1.9508629, 1.9514325, 1.9512864, 1.9504384, 1.9504619, 1.9502065, 1.9500674, 1.9494559, 1.9500169, 1.9491974, 1.9492983, 1.9492034, 1.9493122, 1.9485108, 1.9482579, 1.9479699, 1.9481142, 1.9478569, 1.9479749, 1.9481318, 1.9476713, 1.9472941, 1.9464134, 1.9466743, 1.9461228, 1.9462944, 1.9451288, 1.945171, 1.9448448, 1.9447402, 1.9442545, 1.9436139, 1.9425122, 1.9416131, 1.9405508, 1.9404402, 1.94007, 1.9406945, 1.9404669, 1.9402328, 1.9395534, 1.9391997, 1.9397044, 1.939526, 1.9397131, 1.939988, 1.9390975, 1.9384688, 1.938829, 1.9390311, 1.9386547, 1.9383433, 1.9374398, 1.9372188, 1.9361378, 1.936003, 1.9348307, 1.9347106, 1.9349699, 1.9340439, 1.9336082, 1.9323303, 1.9319574, 1.9312488, 1.93 ...
# real: [1.963, 1.962, 1.962, 1.961, 1.96, 1.96, 1.965, 1.966, 1.965, 1.964, 1.965, 1.964, 1.963, 1.963, 1.963, 1.962, 1.962, 1.96, 1.962, 1.966, 1.962, 1.961, 1.959, 1.958, 1.957, 1.957, 1.956, 1.957, 1.958, 1.956, 1.955, 1.952, 1.952, 1.951, 1.955, 1.957, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.953, 1.952, 1.951, 1.953, 1.956, 1.955, 1.956, 1.955, 1.955, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.948, 1.955, 1.956, 1.956, 1.953, 1.952, 1.951, 1.95, 1.949, 1.948, 1.948, 1.947, 1.947, 1.947, 1.945, 1.945, 1.944, 1.943, 1.943, 1.942, 1.941, 1.94, 1.94, 1.939, 1.939, 1.938, 1.938, 1.937, 1.937, 1.936, 1.935, 1.935, 1.934, 1.933, 1.933, 1.933, 1.932, 1.932, 1.931, 1.931, 1.93, 1.929, 1.929, 1.926, 1.925, 1.924, 1.923, 1.922, 1.921, 1.92, 1.919, 1.918, 1.915, 1.914, 1.912, 1.911, 1.908, 1.907, 1.906, 1.904, 1.902, 1.9, 1.899, 1.897, 1.895, 1.893, 1.892, 1.89, 1.889, 1.886, 1.884, 1.883, 1.881, 1.88, 1.878, 1.876, 1.875, 1.874, 1.872, 1.871, 1.87, 1.863, 1.861, 1.86, 1.855, 1.855, 1.853, 1.852, 1.851, 1.849, 1.848, 1.846, 1.845, 1.844, 1.843, 1.842, 1.843, 1.843, 1.842, 1.839, 1.837, 1.836, 1.834, 1.832, 1.835, 1.834, 1.833, 1.832, 1.831, 1.829, 1.822, 1.82, 1.818, 1.816, 1.821, 1.822, 1.821, 1.818, 1.816, 1.818, 1.818, 1.816, 1.808, 1.805, 1.804, 1.808, 1.808, 1.807, 1.804, 1.803, 1.802, 1.801, 1.799, 1.798, 1.796, 1.795, 1.794, 1.794, 1.794, 1.791, 1.79, 1.787, 1.784, 1.783, 1.781, 1.779, 1.777, 1.775, 1.773, 1.772, 1.77, 1.769, 1.768, 1.766, 1.765, 1.765, 1.764, 1.756, 1.754, 1.751, 1.75, 1.748, 1.749, 1.749, 1.745, 1.745, 1.743, 1.739, 1.736, 1.734, 1.732, 1.729, 1.727, 1.723, 1.721, 1.719, 1.715, 1.714, 1.711, 1.709, 1.707, 1.704, 1.701, 1.702, 1.703, 1.702, 1.699, 1.68, 1.678, 1.675, 1.674, 1.676, 1.967, 1.965, 1.965, 1.964, 1.964, 1.963, 1.965, 1.968, 1.969, 1.968, 1.968, 1.968, 1.967, 1.966, 1.966, 1.966, 1.965, 1.964, 1.965, 1.965, 1.969, 1.966, 1.965, 1.964, 1.963, 1.962, 1.962, 1.961, 1.961, 1.96, 1.961, 1.96, 1.961, 1.961, 1.96, 1.96, 1.959, 1.957, 1.956, 1.956, 1.958, 1.959, 1.959, 1.958, 1.959, 1.958, 1.957, 1.956, 1.955, 1.955, 1.954, 1.953, 1.955, 1.957, 1.957, 1.957, 1.956, 1.956, 1.955, 1.954, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.951, 1.951, 1.949, 1.947, 1.947, 1.947, 1.949, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.942, 1.946, 1.949, 1.95, 1.949, 1.948, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.943, 1.942, 1.942, 1.941, 1.939, 1.938, 1.938, 1.937, 1.936, 1.935, 1.934, 1.933, 1.933, 1.932, 1.932, 1.931, 1.93, 1.93, 1.929, 1.928, 1.928, 1.927, 1.927, 1.926, 1.926, 1.925, 1.925, 1.924, 1.924, 1.923, 1.923, 1.922, 1.921, 1.919, 1.918, 1.918, 1.916, 1.915, 1.914, 1.913, 1.912, 1.911, 1.91, 1.91, 1.909, 1.908, 1.907, 1.905, 1.904, 1.903, 1.902, 1.901, 1.899, 1.898, 1.896, 1.895, 1.891, 1.89, 1.889, 1.887, 1.885, 1.884, 1.882, 1.88, 1.878, 1.877, 1.876, 1.875, 1.873, 1.872, 1.871, 1.863, 1.86, 1.859, 1.862, 1.86, 1.86, 1.864, 1.863, 1.863, 1.863, 1.861, 1.86, 1.858, 1.858, 1.85, 1.848, 1.849, 1.848, 1.848, 1.848, 1.845, 1.844, 1.842, 1.841, 1.84, 1.841, 1.841, 1.84, 1.839, 1.835, 1.833, 1.831, 1.829, 1.827, 1.825, 1.823, 1.824, 1.825, 1.824, 1.822, 1.819, 1.82, 1.82, 1.818, 1.812, 1.81, 1.807, 1.806, 1.807, 1.808, 1.807, 1.804, 1.803, 1.799, 1.799, 1.798, 1.794, 1.791, 1.79, 1.788, 1.785, 1.782, 1.78, 1.776, 1.774, 1.771, 1.769, 1.766, 1.762, 1.759, 1.756, 1.755, 1.752, 1.749, 1.747, 1.746, 1.745, 1.741, 1.739, 1.735, 1.736, 1.733, 1.726, 1.726, 1.724, 1.721, 1.72, 1.718, 1.717, 1.717, 1.714, 1.712, 1.709, 1.708, 1.704, 1.703, 1.701, 1.7, 1.964, 1.962, 1.961, 1.961, 1.961, 1.96, 1.963, 1.965, 1.966, 1.965, 1.965, 1.964, 1.963, 1.963, 1.962, 1.961, 1.961, 1.962, 1.966, 1.963, 1.959, 1.959, 1.958, 1.958, 1.958, 1.958, 1.958, 1.959, 1.958, 1.957, 1.957, 1.954, 1.953, 1.952, 1.954, 1.956, 1.957, 1.956, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.952, 1.954, 1. ...
# 6480

# %% [markdown]
# ## MAE代码

# %%
def calculate_mae(actual, predicted):
    """
    计算两个序列的MAE（平均绝对误差）
    
    参数:
    actual (list or numpy array): 实际值序列
    predicted (list or numpy array): 预测值序列
    
    返回:
    float: MAE值
    """
    # 确保输入序列长度一致
    if len(actual) != len(predicted):
        raise ValueError("实际值序列和预测值序列长度必须一致")
    
    # 计算绝对误差
    absolute_errors = [abs(a - p) for a, p in zip(actual, predicted)]
    
    # 计算平均绝对误差
    mae = sum(absolute_errors) / len(actual)
    
    return mae

# %%
# rmse_all=0
# mae_all=0
# num=0
# for i in range(len(tests)):
#     for j in range(len(tests[0])):
#         real,pred=tests[i][j][0],tests[i][j][1]
#         rmse=evaluation(real,pred)
#         rmse_all+=(rmse)
#         mae_all+=calculate_mae(real,pred)
#         num+=1
# print('RMSE:',[rmse_all/num])
# print('MAE:',mae_all/num)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
test_results,lists=train(seed=0,device=device)
# Out:
# training seed 0:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1420, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0051, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0610, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0314, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0182, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0113, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(9.5344e-05, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(8.4174e-05, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(9.6631e-05, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0001, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0002, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(5.4252e-05, device='cuda:0')

# %%
reals=[]
preds=[]
for i in range(3):
    real,pred=test_results[i][0],test_results[i][1]
    reals.append(real)
    preds.append(pred)
reals=np.concatenate(reals,axis=0)
preds=np.concatenate(preds,axis=0).squeeze()
path='D:/Pywork/CNN_ATTENTION_PINN/new/results/preds/xjtu1.npz'
np.savez(path,reals=reals,preds=preds)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator
# 示例数据
true_soh=np.concatenate((test_results[0][0],test_results[1][0],test_results[2][0]),axis=0)/2
# true_soh = test_results[1][0]
prediction=np.concatenate((test_results[0][1].reshape(-1),test_results[1][1].reshape(-1),test_results[2][1].reshape(-1)),axis=0)/2
# prediction = test_results[1][1].reshape(-1)

print(true_soh)
print(prediction)
def filter_arrays(arr1, arr2, threshold=0.8):
    """
    删除第一个数组中小于阈值的部分，并根据第一个数组删除的索引，删除第二个数组的对应值。

    参数:
    arr1 (np.array): 第一个数组。
    arr2 (np.array): 第二个数组。
    threshold (float): 阈值，默认为0.8。

    返回:
    filtered_arr1 (np.array): 过滤后的第一个数组。
    filtered_arr2 (np.array): 过滤后的第二个数组。
    """
    # 检查两个数组长度是否相同
    if len(arr1) != len(arr2):
        raise ValueError("两个数组的长度必须相同！")

    # 找到第一个数组中大于等于阈值的索引
    valid_indices = arr1 >= threshold

    # 根据索引过滤两个数组
    filtered_arr1 = arr1[valid_indices]
    filtered_arr2 = arr2[valid_indices]

    return filtered_arr1, filtered_arr2
true_soh,prediction=filter_arrays(true_soh,prediction)
# print(true_soh)
# print(prediction.reshape(-1))
distance = np.abs(true_soh - prediction) / np.sqrt(2)
# print(distance)
# 创建散点图
plt.figure(figsize=(8, 7))
scatter = plt.scatter(true_soh, prediction, c=distance, cmap='Blues_r', alpha=1,s=30)

# 添加中间红线
plt.plot([0.80, 1.00], [0.80, 1.00], color='red', linestyle='--')
plt.xticks(np.arange(0.80, 1.01, 0.05),fontsize=25)
plt.yticks(np.arange(0.80, 1.01, 0.05),fontsize=25)
# 添加颜色条
cbar = plt.colorbar(scatter)
cbar.set_label('Absolute error',fontsize=25)
cbar.ax.tick_params(labelsize=24)
# 设置最大刻度数为5
cbar.locator = MaxNLocator(nbins=5)
# 实际显示刻度数 = nbins + 1
cbar.update_ticks()
# 将刻度线画在坐标轴内部
plt.tick_params(axis='both', direction='in')

# 添加标签和标题
plt.xlabel('True SOH',fontsize=30)
plt.ylabel('Prediction',fontsize=30)
plt.title('XJTU batch-1',fontsize=30)
# plt.legend()

# 显示图表
plt.show()
# Out:
# [0.9815 0.981  0.981  ... 0.82   0.8185 0.818 ]
# [0.97687244 0.97722197 0.9775724  ... 0.84010965 0.840205   0.8409227 ]

# %% [markdown]
# # MLP

# %%
class MLP(nn.Module):
    def __init__(self, input_size=11, output_size=1):
        super(MLP, self).__init__()
        self.net = nn.Sequential(nn.Linear(input_size, 32),
                                 nn.ReLU(),
                                 nn.Linear(32, 64),
                                 nn.ReLU(),
                                 nn.Linear(64, 128),
                                 nn.ReLU(),
                                 nn.Linear(128, 256),
                                 nn.ReLU(),
                                 nn.Linear(256, 128),
                                 nn.ReLU(),
                                 nn.Linear(128, 64),
                                 nn.ReLU(),
                                 nn.Linear(64, output_size))
    def forward(self, x):
        return self.net(x)
def train_mlp(lr=0.001,epochs=150, weight_decay=1e-4, seed=0, metric='rmse', device='cpu'):
    """function for train"""
    setup_seed(seed)
    print("training seed "+str(seed)+':\n')
    train_loader, val_loader, test_35_data, test_36_data, test_37_data=get_data()
    test_data=[test_35_data, test_36_data, test_37_data]
    model = MLP()
    model=model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.MSELoss()
    len_dataloader = len(train_loader)
    test_results=[]
    """早停止获取最佳模型"""
    val_mse=10
    for epoch in range(epochs):
        loss_epoch=0
        for X,y in train_loader:
            X,y = X.to(device), y.to(device)
            y_pred= model(X)
            y_pred = y_pred.squeeze(1)
            loss = criterion(y_pred,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_epoch += loss
        if (epoch+1)%5==0 and epoch!=0:
            print('Epoch:',epoch+1,'Train_RMSELoss:',loss_epoch/len_dataloader,'\n')
        if (epoch+1)%5==0 and epoch!=0:
            val_loss=0
            for val_x,val_y in val_loader:
                val_x,val_y=val_x.to(device),val_y.to(device)
                pre=model(val_x)
                val_loss+=criterion(pre.squeeze(1),val_y).detach()    
            print('Epoch:',epoch+1,'valid_RMSELoss:',val_loss/len(val_loader),'\n')
            val_mse=val_loss/len(val_loader)
                
        if (val_mse<10e-6 and epoch>=35)or (epoch+1)==epochs:
            model=model.cpu()
            for name in test_data:
                X=torch.from_numpy(name[0]).float()
                y=name[1]
                y_pred=model(X)
                y_pred= y_pred.squeeze(0).detach().numpy()
                test_results.append([y,y_pred])
            break
    return test_results
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
tests_mlp=[]
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
for i in range(5):
    test_result=train_mlp(seed=i,device=device)
    tests_mlp.append(test_result)
# Out:
# training seed 0:
#
# Epoch: 5 Train_RMSELoss: tensor(0.5914, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.4383, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0526, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0181, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0050, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0105, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0068, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0069, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0068, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0094, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0069, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0036, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0049, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0031, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0039, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0049, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0117, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0193, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0036, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0020, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0014, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0016, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0019, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0062, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0049, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0037, device='cuda:0')
#
# training seed 1:
#
# Epoch: 5 Train_RMSELoss: tensor(0.6459, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.5999, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0496, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0091, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0023, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0039, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0090, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0167, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0096, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0208, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0065, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0238, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0035, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0049, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0075, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0076, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0125, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0126, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0038, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0031, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0080, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0057, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0025, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0054, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0036, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0051, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0025, device='cuda:0')
#
# training seed 2:
#
# Epoch: 5 Train_RMSELoss: tensor(0.7765, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.7683, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0151, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0073, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0291, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0400, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0025, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0084, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0036, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0016, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0027, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0146, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0028, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0061, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0093, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0031, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0041, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0116, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0199, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0049, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# training seed 3:
#
# Epoch: 5 Train_RMSELoss: tensor(0.6186, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.4747, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0277, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0587, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0038, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0079, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0062, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0020, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0069, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0109, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0086, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0157, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0059, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0069, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0020, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0038, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0115, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0020, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0037, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0115, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0027, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0028, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0042, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0038, device='cuda:0')
#
# training seed 4:
#
# Epoch: 5 Train_RMSELoss: tensor(0.3559, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.2006, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0193, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0164, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0050, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0125, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0188, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0065, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0112, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0110, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0030, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0064, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0021, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0037, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0055, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0058, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0035, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0014, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0041, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0018, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0118, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0091, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0005, device='cuda:0')

# %%
rmse_all=[]
mae_all=[]
mape_all=[]
r2=[]
num=0
test_csv_m=[]
real_csv_m=[]
for i in range(4):
    for j in range(len(tests[0])):
        real,pred=tests_mlp[i][j][0],tests_mlp[i][j][1].reshape(-1)
        rmse=evaluation(real,pred)
        if rmse>=0.00:
            rmse_all.append(rmse)
            for pre,rea in zip(pred,real):
                test_csv_m.append(pre)
                real_csv_m.append(rea)
        mae_all.append(calculate_mae(real,pred))
        mape_all.append(mape(real,pred))
        r2.append(r_squared(real,pred))
        num+=1
print("RMSE:",rmse_all)
print("test:",test_csv_m)
print('real:',real_csv_m)
len(test_csv_m)
# Out:
# RMSE: [0.06579309963625525, 0.04369057865227705, 0.07827775554412972, 0.054498844378237786, 0.03015673380193217, 0.05696909486989024, 0.047771423017905545, 0.07634437184544592, 0.05322217859457591, 0.06438953793415107, 0.04106047272341061, 0.08376067756217095]
# test: [1.9783419, 1.9930364, 2.0076125, 2.013209, 2.0052583, 1.9952407, 1.9891001, 1.982112, 1.9801968, 1.9879245, 2.0004406, 2.0050478, 2.0089183, 2.005451, 2.0007381, 1.9964179, 1.9936289, 1.9937927, 1.9965345, 1.9923931, 1.9893587, 1.987604, 1.9836841, 1.9811462, 1.9767555, 1.9721684, 1.9697926, 1.9712226, 1.9717046, 1.9690915, 1.9659452, 1.96814, 1.9700738, 1.9677821, 1.9726198, 1.9732922, 1.9721942, 1.9742447, 1.9734122, 1.973393, 1.9737891, 1.9748913, 1.9753982, 1.9763905, 1.9782592, 1.9786667, 1.98041, 1.9814152, 1.9818599, 1.9822819, 1.9828662, 1.9805647, 1.9814078, 1.9833852, 1.9854901, 1.9847124, 1.9855019, 1.9844364, 1.9846395, 1.9850485, 1.987139, 1.9845613, 1.9839524, 1.9818798, 1.9809242, 1.979842, 1.9798709, 1.9805814, 1.982279, 1.9865782, 1.9875826, 1.9869897, 1.9845631, 1.9872166, 1.9853235, 1.9829446, 1.9900124, 1.9926406, 1.9957606, 1.9973505, 1.9975837, 1.9963055, 1.9966809, 1.9963739, 1.9934419, 1.9930573, 1.9913776, 1.9930022, 1.9955015, 1.9931669, 1.9927202, 1.9941642, 1.9906013, 1.986678, 1.9815134, 1.9804924, 1.9773911, 1.9759737, 1.9763104, 1.9720259, 1.9749244, 1.9765161, 1.9758219, 1.9739555, 1.9765421, 1.9763765, 1.9735566, 1.9732722, 1.9759332, 1.9776589, 1.9787846, 1.9788845, 1.9807731, 1.9803814, 1.9806365, 1.9812783, 1.9800972, 1.9852272, 1.9841124, 1.9845742, 1.985801, 1.9852403, 1.9809947, 1.9775435, 1.9779875, 1.9720155, 1.9686891, 1.9690127, 1.9710157, 1.9700692, 1.9703281, 1.96739, 1.9651152, 1.9640048, 1.9600284, 1.9619116, 1.9599534, 1.9585354, 1.9576042, 1.9552515, 1.9587802, 1.9551038, 1.9547138, 1.9506896, 1.9450089, 1.9409894, 1.9337628, 1.9282868, 1.9282349, 1.9252112, 1.925069, 1.9253293, 1.9224788, 1.9169797, 1.9117463, 1.8939854, 1.8917338, 1.8943112, 1.8703732, 1.8732821, 1.8666695, 1.8608078, 1.8580445, 1.859061, 1.8604566, 1.8594816, 1.8593396, 1.8572598, 1.8575815, 1.8542112, 1.8510469, 1.8463739, 1.8481861, 1.8499668, 1.8522547, 1.8414285, 1.8455136, 1.8381886, 1.8433275, 1.8414725, 1.8421377, 1.8438061, 1.8455377, 1.8431085, 1.8486726, 1.850416, 1.8488883, 1.8471605, 1.8477677, 1.8505646, 1.8514482, 1.8545178, 1.8587217, 1.8571278, 1.8642055, 1.8650047, 1.8602971, 1.862047, 1.85738, 1.8628589, 1.8530844, 1.852822, 1.853002, 1.855347, 1.8646172, 1.8679203, 1.867847, 1.8682046, 1.8777564, 1.8914462, 1.8873788, 1.8865039, 1.8908027, 1.8953649, 1.8981096, 1.9013296, 1.8985943, 1.8904283, 1.8857156, 1.8848324, 1.8801957, 1.8835958, 1.8900189, 1.8869089, 1.8894993, 1.8880911, 1.8858179, 1.8769386, 1.86659, 1.8725795, 1.8703018, 1.8527837, 1.8447759, 1.8491255, 1.8560967, 1.8589656, 1.8576247, 1.8632969, 1.8629605, 1.8568972, 1.8469012, 1.8436159, 1.8411644, 1.835985, 1.8316926, 1.832318, 1.8155721, 1.8114191, 1.8174115, 1.8174027, 1.821565, 1.8226366, 1.8218358, 1.8214577, 1.8217801, 1.8213593, 1.8188316, 1.8166026, 1.821284, 1.8188349, 1.8177508, 1.837486, 1.8418977, 1.8402985, 1.8405175, 1.8380767, 1.9893025, 2.003997, 2.0184956, 2.0245686, 2.0173979, 2.0057528, 1.9997848, 1.9928778, 1.9851302, 1.9939613, 2.000175, 2.005028, 2.0082176, 2.0074413, 2.0086746, 2.0140288, 2.0155354, 2.012285, 2.0122414, 2.011401, 2.0007436, 1.9989609, 1.9984046, 1.995021, 1.9965459, 1.9985818, 1.9950408, 1.9938639, 1.9906211, 1.9862603, 1.9839872, 1.9862598, 1.9864012, 1.9895974, 1.9898385, 1.9913895, 1.9865093, 1.9906462, 1.9910852, 1.9882983, 1.9901934, 1.9890615, 1.9889448, 1.9880077, 1.9914733, 1.9875834, 1.9895381, 1.9896227, 1.9909776, 1.987374, 1.9852886, 1.9839312, 1.983917, 1.9835886, 1.9858786, 1.9886001, 1.9872884, 1.98554, 1.9832599, 1.9852155, 1.984789, 1.9857627, 1.9798976, 1.9820994, 1.9811049, 1.980924, 1.978997, 1.9756998, 1.9722224, 1.9708576, 1.9676079, 1.9682044, 1.9676265, 1.9736501, 1.9738523, 1.9758352, 1.9731522, 1.9738239, 1.9797915, 1.9789394, 1.9816105, 1.9849409, 1.9814144, 1.9799677, 1.9841532, 1.9882654, 1.9877151, 1.9874978, 1.9842571, 1.9830933, 1.9790488, 1.9797217, 1.974611, 1.9753593, 1.979315, 1.9775058, 1.9773632, 1.9751252, 1.9757037, 1.9736729, 1.9698929, 1.96 ...
# real: [1.963, 1.962, 1.962, 1.961, 1.96, 1.96, 1.965, 1.966, 1.965, 1.964, 1.965, 1.964, 1.963, 1.963, 1.963, 1.962, 1.962, 1.96, 1.962, 1.966, 1.962, 1.961, 1.959, 1.958, 1.957, 1.957, 1.956, 1.957, 1.958, 1.956, 1.955, 1.952, 1.952, 1.951, 1.955, 1.957, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.953, 1.952, 1.951, 1.953, 1.956, 1.955, 1.956, 1.955, 1.955, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.948, 1.955, 1.956, 1.956, 1.953, 1.952, 1.951, 1.95, 1.949, 1.948, 1.948, 1.947, 1.947, 1.947, 1.945, 1.945, 1.944, 1.943, 1.943, 1.942, 1.941, 1.94, 1.94, 1.939, 1.939, 1.938, 1.938, 1.937, 1.937, 1.936, 1.935, 1.935, 1.934, 1.933, 1.933, 1.933, 1.932, 1.932, 1.931, 1.931, 1.93, 1.929, 1.929, 1.926, 1.925, 1.924, 1.923, 1.922, 1.921, 1.92, 1.919, 1.918, 1.915, 1.914, 1.912, 1.911, 1.908, 1.907, 1.906, 1.904, 1.902, 1.9, 1.899, 1.897, 1.895, 1.893, 1.892, 1.89, 1.889, 1.886, 1.884, 1.883, 1.881, 1.88, 1.878, 1.876, 1.875, 1.874, 1.872, 1.871, 1.87, 1.863, 1.861, 1.86, 1.855, 1.855, 1.853, 1.852, 1.851, 1.849, 1.848, 1.846, 1.845, 1.844, 1.843, 1.842, 1.843, 1.843, 1.842, 1.839, 1.837, 1.836, 1.834, 1.832, 1.835, 1.834, 1.833, 1.832, 1.831, 1.829, 1.822, 1.82, 1.818, 1.816, 1.821, 1.822, 1.821, 1.818, 1.816, 1.818, 1.818, 1.816, 1.808, 1.805, 1.804, 1.808, 1.808, 1.807, 1.804, 1.803, 1.802, 1.801, 1.799, 1.798, 1.796, 1.795, 1.794, 1.794, 1.794, 1.791, 1.79, 1.787, 1.784, 1.783, 1.781, 1.779, 1.777, 1.775, 1.773, 1.772, 1.77, 1.769, 1.768, 1.766, 1.765, 1.765, 1.764, 1.756, 1.754, 1.751, 1.75, 1.748, 1.749, 1.749, 1.745, 1.745, 1.743, 1.739, 1.736, 1.734, 1.732, 1.729, 1.727, 1.723, 1.721, 1.719, 1.715, 1.714, 1.711, 1.709, 1.707, 1.704, 1.701, 1.702, 1.703, 1.702, 1.699, 1.68, 1.678, 1.675, 1.674, 1.676, 1.967, 1.965, 1.965, 1.964, 1.964, 1.963, 1.965, 1.968, 1.969, 1.968, 1.968, 1.968, 1.967, 1.966, 1.966, 1.966, 1.965, 1.964, 1.965, 1.965, 1.969, 1.966, 1.965, 1.964, 1.963, 1.962, 1.962, 1.961, 1.961, 1.96, 1.961, 1.96, 1.961, 1.961, 1.96, 1.96, 1.959, 1.957, 1.956, 1.956, 1.958, 1.959, 1.959, 1.958, 1.959, 1.958, 1.957, 1.956, 1.955, 1.955, 1.954, 1.953, 1.955, 1.957, 1.957, 1.957, 1.956, 1.956, 1.955, 1.954, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.951, 1.951, 1.949, 1.947, 1.947, 1.947, 1.949, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.942, 1.946, 1.949, 1.95, 1.949, 1.948, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.943, 1.942, 1.942, 1.941, 1.939, 1.938, 1.938, 1.937, 1.936, 1.935, 1.934, 1.933, 1.933, 1.932, 1.932, 1.931, 1.93, 1.93, 1.929, 1.928, 1.928, 1.927, 1.927, 1.926, 1.926, 1.925, 1.925, 1.924, 1.924, 1.923, 1.923, 1.922, 1.921, 1.919, 1.918, 1.918, 1.916, 1.915, 1.914, 1.913, 1.912, 1.911, 1.91, 1.91, 1.909, 1.908, 1.907, 1.905, 1.904, 1.903, 1.902, 1.901, 1.899, 1.898, 1.896, 1.895, 1.891, 1.89, 1.889, 1.887, 1.885, 1.884, 1.882, 1.88, 1.878, 1.877, 1.876, 1.875, 1.873, 1.872, 1.871, 1.863, 1.86, 1.859, 1.862, 1.86, 1.86, 1.864, 1.863, 1.863, 1.863, 1.861, 1.86, 1.858, 1.858, 1.85, 1.848, 1.849, 1.848, 1.848, 1.848, 1.845, 1.844, 1.842, 1.841, 1.84, 1.841, 1.841, 1.84, 1.839, 1.835, 1.833, 1.831, 1.829, 1.827, 1.825, 1.823, 1.824, 1.825, 1.824, 1.822, 1.819, 1.82, 1.82, 1.818, 1.812, 1.81, 1.807, 1.806, 1.807, 1.808, 1.807, 1.804, 1.803, 1.799, 1.799, 1.798, 1.794, 1.791, 1.79, 1.788, 1.785, 1.782, 1.78, 1.776, 1.774, 1.771, 1.769, 1.766, 1.762, 1.759, 1.756, 1.755, 1.752, 1.749, 1.747, 1.746, 1.745, 1.741, 1.739, 1.735, 1.736, 1.733, 1.726, 1.726, 1.724, 1.721, 1.72, 1.718, 1.717, 1.717, 1.714, 1.712, 1.709, 1.708, 1.704, 1.703, 1.701, 1.7, 1.964, 1.962, 1.961, 1.961, 1.961, 1.96, 1.963, 1.965, 1.966, 1.965, 1.965, 1.964, 1.963, 1.963, 1.962, 1.961, 1.961, 1.962, 1.966, 1.963, 1.959, 1.959, 1.958, 1.958, 1.958, 1.958, 1.958, 1.959, 1.958, 1.957, 1.957, 1.954, 1.953, 1.952, 1.954, 1.956, 1.957, 1.956, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.952, 1.954, 1. ...
# 6480

# %%
# rmse_all=0
# mae_all=0
# num=0
# for i in range(len(tests_mlp)):
#     for j in range(len(tests_mlp[0])):
#         real,pred=tests_mlp[i][j][0],tests_mlp[i][j][1]
#         rmse=evaluation(real,pred)
#         rmse_all+=(rmse)
#         mae_all+=calculate_mae(real,pred)
#         num+=1
# print('RMSE:',[rmse_all/num])
# print('MAE:',mae_all/num)
# Out:
# RMSE: [0.047205495197372674]
# MAE: [0.03864157]

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input=11):
        super(ConvNet, self).__init__()
        # 输入重塑为 (batch, 1, n_input)
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(32 * (n_input // 2), 64)  # 根据池化后的维度调整
        self.fc2 = nn.Sequential(nn.Linear(64 , 256),
                                 nn.ReLU(),
                                 nn.Linear(256, 64),
                                 nn.ReLU(),
                                 nn.Linear(64, 32),
                                 nn.ReLU(),
                                 nn.Linear(32, 1),)
    
    def forward(self, x):
        # 输入 x 的形状: (batch, n_input)
        x = x.unsqueeze(1)  # 重塑为 (batch, 1, n_input)
        x = self.conv1(x)   # 卷积后形状: (batch, 32, n_input)
        x = self.relu(x)
        x = self.pool(x)    # 池化后形状: (batch, 32, n_input // 2)
        x = x.view(x.size(0), -1)  # 展平为 (batch, 32 * (n_input // 2))
        x = self.fc1(x)     # 全连接层
        x = self.relu(x)
        x = self.fc2(x)     # 输出形状: (batch, 1)
        return x
def train_conv(lr=0.001,epochs=150, weight_decay=1e-4, seed=0, metric='rmse', device='cpu'):
    """function for train"""
    setup_seed(seed)
    print("training seed "+str(seed)+':\n')
    train_loader, val_loader, test_35_data, test_36_data, test_37_data=get_data()
    test_data=[test_35_data, test_36_data, test_37_data]
    model = ConvNet()
    model=model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.MSELoss()
    len_dataloader = len(train_loader)
    test_results=[]
    """早停止获取最佳模型"""
    val_mse=10
    for epoch in range(epochs):
        loss_epoch=0
        for X,y in train_loader:
            X,y = X.to(device), y.to(device)
            y_pred= model(X)
            y_pred = y_pred.squeeze(1)
            loss = criterion(y_pred,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_epoch += loss
        if (epoch+1)%5==0 and epoch!=0:
            print('Epoch:',epoch+1,'Train_RMSELoss:',loss_epoch/len_dataloader,'\n')
        if (epoch+1)%5==0 and epoch!=0:
            val_loss=0
            for val_x,val_y in val_loader:
                val_x,val_y=val_x.to(device),val_y.to(device)
                pre=model(val_x)
                val_loss+=criterion(pre.squeeze(1),val_y).detach()    
            print('Epoch:',epoch+1,'valid_RMSELoss:',val_loss/len(val_loader),'\n')
            val_mse=val_loss/len(val_loader)
                
        if (val_mse<5e-5 and epoch>=10)or (epoch+1)==epochs:
            model=model.cpu()
            for name in test_data:
                X=torch.from_numpy(name[0]).float()
                y=name[1]
                y_pred=model(X)
                y_pred= y_pred.squeeze(0).detach().numpy()
                test_results.append([y,y_pred])
            break
    return test_results
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
tests_cnn=[]
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
for i in range(5):
    test_result=train_conv(seed=i,device=device)
    tests_cnn.append(test_result)
# Out:
# training seed 0:
#
# Epoch: 5 Train_RMSELoss: tensor(0.3934, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.2041, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0246, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0249, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0250, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0123, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0079, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0088, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0266, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0340, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0068, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0048, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0118, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0136, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0082, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0043, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0078, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0126, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0170, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0030, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0028, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0068, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0202, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0039, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0016, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0028, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0071, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0016, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0163, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0220, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# training seed 1:
#
# Epoch: 5 Train_RMSELoss: tensor(0.3696, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.2876, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0217, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0174, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0147, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0082, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0184, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0164, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0065, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0053, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0086, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0071, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0095, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0052, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0065, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0126, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0169, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0042, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0048, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0147, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0029, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0019, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0041, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0036, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0032, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# training seed 2:
#
# Epoch: 5 Train_RMSELoss: tensor(0.0715, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0391, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0090, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0063, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0077, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0039, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0057, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0089, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0064, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0067, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0058, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0058, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0028, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# training seed 3:
#
# Epoch: 5 Train_RMSELoss: tensor(0.1157, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.1190, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0128, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0255, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0072, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0112, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0159, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0099, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0150, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0068, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0058, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0071, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0060, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0096, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0105, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0057, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0101, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0048, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0091, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0076, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0040, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0027, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0050, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0022, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0071, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0178, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0027, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0072, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0041, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0050, device='cuda:0')
#
# training seed 4:
#
# Epoch: 5 Train_RMSELoss: tensor(0.6481, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.4961, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0175, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0073, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0072, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0064, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0082, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0038, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0087, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0055, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0032, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0019, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0014, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0042, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0169, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0237, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0023, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0046, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0118, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0034, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0022, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0091, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0037, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0018, device='cuda:0')

# %%
rmse_all=[]
mae_all=[]
mape_all=[]
r2=[]
num=0
test_csv_c=[]
real_csv_c=[]
for i in range(4):
    for j in range(len(tests[0])):
        real,pred=tests_cnn[i][j][0],tests_cnn[i][j][1].reshape(-1)
        rmse=evaluation(real,pred)
        if rmse>=0.00:
            rmse_all.append(rmse)
            for pre,rea in zip(pred,real):
                test_csv_c.append(pre)
                real_csv_c.append(rea)
        mae_all.append(calculate_mae(real,pred))
        mape_all.append(mape(real,pred))
        r2.append(r_squared(real,pred))
        num+=1
print("RMSE:",rmse_all)
print("test:",test_csv_c)
print('real:',real_csv_c)
len(test_csv_c)
# Out:
# RMSE: [0.026876875666067716, 0.03667581140951337, 0.03262136518974459, 0.0256826560034684, 0.03793627614116888, 0.04461663008145203, 0.020440473757718788, 0.027164748638271043, 0.02745706394945903, 0.07214482056667017, 0.0934308085398261, 0.06110497562697104]
# test: [1.9305291, 1.9391352, 1.9417211, 1.9414262, 1.9416263, 1.9414591, 1.9412313, 1.9410135, 1.9424206, 1.946821, 1.9562334, 1.9565414, 1.9577148, 1.9609038, 1.9579908, 1.9543207, 1.9513149, 1.9520112, 1.9536532, 1.9462477, 1.9397581, 1.9383911, 1.9346457, 1.9323089, 1.9207755, 1.9173706, 1.9143149, 1.9161091, 1.916301, 1.9145496, 1.9106654, 1.9110394, 1.9119263, 1.9076035, 1.9127916, 1.9128464, 1.9114112, 1.9136225, 1.9125451, 1.9133303, 1.9153024, 1.9183891, 1.9200779, 1.9202868, 1.923734, 1.9244787, 1.9239228, 1.9261378, 1.9261335, 1.9281925, 1.9282331, 1.9264562, 1.9277047, 1.93342, 1.9342442, 1.9324211, 1.9329022, 1.9304911, 1.9290968, 1.9276642, 1.9300681, 1.9281818, 1.926776, 1.9360262, 1.9321516, 1.9301649, 1.9290824, 1.9310752, 1.9310015, 1.9340726, 1.934426, 1.9335123, 1.9300047, 1.9317483, 1.9296468, 1.9264699, 1.9313914, 1.9293472, 1.9316679, 1.9312423, 1.9286686, 1.9281166, 1.930043, 1.9290497, 1.9237951, 1.9219692, 1.9191693, 1.918494, 1.9184233, 1.916457, 1.9143499, 1.914158, 1.9095485, 1.9062024, 1.8994485, 1.8990281, 1.8955009, 1.8887736, 1.8881586, 1.8846796, 1.8889169, 1.889762, 1.8886214, 1.8848447, 1.8857726, 1.8850042, 1.8835481, 1.8845491, 1.8879617, 1.8904718, 1.8922324, 1.8954637, 1.8986486, 1.898564, 1.897942, 1.9009202, 1.9031138, 1.909981, 1.9099702, 1.9109933, 1.9146914, 1.9166762, 1.9145023, 1.9120513, 1.9145358, 1.9081717, 1.9054382, 1.9062892, 1.9097015, 1.9106251, 1.9097492, 1.9048921, 1.903006, 1.8998045, 1.8952445, 1.895928, 1.8948687, 1.8944446, 1.8957342, 1.8906319, 1.8945787, 1.8926964, 1.8941449, 1.8904886, 1.8870482, 1.8823051, 1.8741316, 1.8703614, 1.8720077, 1.8691694, 1.8694946, 1.8679274, 1.8691816, 1.8636538, 1.8614237, 1.8354954, 1.8345939, 1.8385781, 1.779013, 1.7793856, 1.7679981, 1.7603998, 1.7560937, 1.758994, 1.7631453, 1.7633847, 1.7735989, 1.7742476, 1.7826713, 1.7915775, 1.7921796, 1.7895674, 1.7927568, 1.7935988, 1.794009, 1.7926971, 1.7955328, 1.7931393, 1.80691, 1.8076578, 1.8114904, 1.8146597, 1.816053, 1.8116106, 1.8185177, 1.8182626, 1.8102577, 1.8121157, 1.8119358, 1.8182361, 1.8256525, 1.8281037, 1.8319734, 1.8283186, 1.8359954, 1.8290671, 1.8266752, 1.8291185, 1.8338909, 1.83919, 1.834129, 1.8307161, 1.8289778, 1.8278892, 1.8274964, 1.8354712, 1.8380135, 1.833612, 1.8553921, 1.8656826, 1.8670901, 1.859811, 1.867311, 1.8848761, 1.8813378, 1.8828876, 1.8694991, 1.8676627, 1.8614097, 1.8537291, 1.8484018, 1.8530749, 1.8610107, 1.8597925, 1.8548133, 1.8423514, 1.84398, 1.8241619, 1.8097199, 1.8187753, 1.8238147, 1.7957308, 1.7893695, 1.7938474, 1.7870296, 1.7898746, 1.7995087, 1.8114084, 1.8097073, 1.7981026, 1.7863787, 1.7829512, 1.782122, 1.7733599, 1.7733022, 1.7696574, 1.7449256, 1.7391561, 1.7296821, 1.7243941, 1.7236131, 1.7201602, 1.7150333, 1.7126179, 1.7016479, 1.6870165, 1.6791028, 1.6730663, 1.6755329, 1.6728985, 1.6699195, 1.7275953, 1.7387359, 1.7411212, 1.7414631, 1.7363986, 1.9532778, 1.9609183, 1.9644417, 1.9640464, 1.9644738, 1.9642371, 1.9639503, 1.9636495, 1.9612645, 1.9630488, 1.961519, 1.9645162, 1.9702466, 1.9745132, 1.973879, 1.9790651, 1.9826549, 1.9790908, 1.9789599, 1.9762999, 1.9662954, 1.9637939, 1.9604579, 1.9581505, 1.9594321, 1.9627725, 1.9570191, 1.9551326, 1.9487824, 1.9437529, 1.9417741, 1.9434121, 1.9420251, 1.9459434, 1.9469444, 1.9481593, 1.9456908, 1.9508963, 1.9507045, 1.9481012, 1.9489523, 1.9479963, 1.9470717, 1.9475766, 1.9519883, 1.9512386, 1.956845, 1.958235, 1.9615946, 1.9617763, 1.9606093, 1.9594167, 1.958343, 1.957674, 1.9594004, 1.961447, 1.9590125, 1.955296, 1.9544119, 1.9551911, 1.9543158, 1.9518301, 1.9448853, 1.946281, 1.944431, 1.93994, 1.9366118, 1.9318597, 1.9286273, 1.9290224, 1.9238783, 1.9217683, 1.9198968, 1.9235984, 1.9227328, 1.9222188, 1.9170105, 1.9182577, 1.9228089, 1.918104, 1.9200146, 1.9218869, 1.9220465, 1.920738, 1.923831, 1.9262753, 1.9249562, 1.9250562, 1.9210596, 1.9192495, 1.917561, 1.9182055, 1.9178206, 1.917396, 1.9242104, 1.9212842, 1.9187793, 1.9217106, 1.9188204, 1.9148555, 1.9126527, 1.907 ...
# real: [1.963, 1.962, 1.962, 1.961, 1.96, 1.96, 1.965, 1.966, 1.965, 1.964, 1.965, 1.964, 1.963, 1.963, 1.963, 1.962, 1.962, 1.96, 1.962, 1.966, 1.962, 1.961, 1.959, 1.958, 1.957, 1.957, 1.956, 1.957, 1.958, 1.956, 1.955, 1.952, 1.952, 1.951, 1.955, 1.957, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.953, 1.952, 1.951, 1.953, 1.956, 1.955, 1.956, 1.955, 1.955, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.948, 1.955, 1.956, 1.956, 1.953, 1.952, 1.951, 1.95, 1.949, 1.948, 1.948, 1.947, 1.947, 1.947, 1.945, 1.945, 1.944, 1.943, 1.943, 1.942, 1.941, 1.94, 1.94, 1.939, 1.939, 1.938, 1.938, 1.937, 1.937, 1.936, 1.935, 1.935, 1.934, 1.933, 1.933, 1.933, 1.932, 1.932, 1.931, 1.931, 1.93, 1.929, 1.929, 1.926, 1.925, 1.924, 1.923, 1.922, 1.921, 1.92, 1.919, 1.918, 1.915, 1.914, 1.912, 1.911, 1.908, 1.907, 1.906, 1.904, 1.902, 1.9, 1.899, 1.897, 1.895, 1.893, 1.892, 1.89, 1.889, 1.886, 1.884, 1.883, 1.881, 1.88, 1.878, 1.876, 1.875, 1.874, 1.872, 1.871, 1.87, 1.863, 1.861, 1.86, 1.855, 1.855, 1.853, 1.852, 1.851, 1.849, 1.848, 1.846, 1.845, 1.844, 1.843, 1.842, 1.843, 1.843, 1.842, 1.839, 1.837, 1.836, 1.834, 1.832, 1.835, 1.834, 1.833, 1.832, 1.831, 1.829, 1.822, 1.82, 1.818, 1.816, 1.821, 1.822, 1.821, 1.818, 1.816, 1.818, 1.818, 1.816, 1.808, 1.805, 1.804, 1.808, 1.808, 1.807, 1.804, 1.803, 1.802, 1.801, 1.799, 1.798, 1.796, 1.795, 1.794, 1.794, 1.794, 1.791, 1.79, 1.787, 1.784, 1.783, 1.781, 1.779, 1.777, 1.775, 1.773, 1.772, 1.77, 1.769, 1.768, 1.766, 1.765, 1.765, 1.764, 1.756, 1.754, 1.751, 1.75, 1.748, 1.749, 1.749, 1.745, 1.745, 1.743, 1.739, 1.736, 1.734, 1.732, 1.729, 1.727, 1.723, 1.721, 1.719, 1.715, 1.714, 1.711, 1.709, 1.707, 1.704, 1.701, 1.702, 1.703, 1.702, 1.699, 1.68, 1.678, 1.675, 1.674, 1.676, 1.967, 1.965, 1.965, 1.964, 1.964, 1.963, 1.965, 1.968, 1.969, 1.968, 1.968, 1.968, 1.967, 1.966, 1.966, 1.966, 1.965, 1.964, 1.965, 1.965, 1.969, 1.966, 1.965, 1.964, 1.963, 1.962, 1.962, 1.961, 1.961, 1.96, 1.961, 1.96, 1.961, 1.961, 1.96, 1.96, 1.959, 1.957, 1.956, 1.956, 1.958, 1.959, 1.959, 1.958, 1.959, 1.958, 1.957, 1.956, 1.955, 1.955, 1.954, 1.953, 1.955, 1.957, 1.957, 1.957, 1.956, 1.956, 1.955, 1.954, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.951, 1.951, 1.949, 1.947, 1.947, 1.947, 1.949, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.942, 1.946, 1.949, 1.95, 1.949, 1.948, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.943, 1.942, 1.942, 1.941, 1.939, 1.938, 1.938, 1.937, 1.936, 1.935, 1.934, 1.933, 1.933, 1.932, 1.932, 1.931, 1.93, 1.93, 1.929, 1.928, 1.928, 1.927, 1.927, 1.926, 1.926, 1.925, 1.925, 1.924, 1.924, 1.923, 1.923, 1.922, 1.921, 1.919, 1.918, 1.918, 1.916, 1.915, 1.914, 1.913, 1.912, 1.911, 1.91, 1.91, 1.909, 1.908, 1.907, 1.905, 1.904, 1.903, 1.902, 1.901, 1.899, 1.898, 1.896, 1.895, 1.891, 1.89, 1.889, 1.887, 1.885, 1.884, 1.882, 1.88, 1.878, 1.877, 1.876, 1.875, 1.873, 1.872, 1.871, 1.863, 1.86, 1.859, 1.862, 1.86, 1.86, 1.864, 1.863, 1.863, 1.863, 1.861, 1.86, 1.858, 1.858, 1.85, 1.848, 1.849, 1.848, 1.848, 1.848, 1.845, 1.844, 1.842, 1.841, 1.84, 1.841, 1.841, 1.84, 1.839, 1.835, 1.833, 1.831, 1.829, 1.827, 1.825, 1.823, 1.824, 1.825, 1.824, 1.822, 1.819, 1.82, 1.82, 1.818, 1.812, 1.81, 1.807, 1.806, 1.807, 1.808, 1.807, 1.804, 1.803, 1.799, 1.799, 1.798, 1.794, 1.791, 1.79, 1.788, 1.785, 1.782, 1.78, 1.776, 1.774, 1.771, 1.769, 1.766, 1.762, 1.759, 1.756, 1.755, 1.752, 1.749, 1.747, 1.746, 1.745, 1.741, 1.739, 1.735, 1.736, 1.733, 1.726, 1.726, 1.724, 1.721, 1.72, 1.718, 1.717, 1.717, 1.714, 1.712, 1.709, 1.708, 1.704, 1.703, 1.701, 1.7, 1.964, 1.962, 1.961, 1.961, 1.961, 1.96, 1.963, 1.965, 1.966, 1.965, 1.965, 1.964, 1.963, 1.963, 1.962, 1.961, 1.961, 1.962, 1.966, 1.963, 1.959, 1.959, 1.958, 1.958, 1.958, 1.958, 1.958, 1.959, 1.958, 1.957, 1.957, 1.954, 1.953, 1.952, 1.954, 1.956, 1.957, 1.956, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.952, 1.954, 1. ...
# 6480

# %%
class LSTMNetwork(nn.Module):
    def __init__(self, input_size=11, hidden_size=60, num_layers=6, output_size=1):
        """
        LSTM网络初始化
        :param input_size: 输入特征的维度 (n)
        :param hidden_size: 隐藏层的维度
        :param num_layers: LSTM的层数
        :param output_size: 输出的维度 (1)
        """
        super(LSTMNetwork, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # 定义LSTM层
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        # 定义全连接层，将LSTM的输出映射到输出维度
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        """
        前向传播
        :param x: 输入数据，形状为 (batch_size, input_size)
        :return: 输出数据，形状为 (batch_size, output_size)
        """
        # 添加序列维度 (sequence_length=1)
        x = x.unsqueeze(1)  # 形状变为 (batch_size, 1, input_size)

        # 初始化隐藏状态和细胞状态
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # LSTM前向传播
        out, _ = self.lstm(x, (h0, c0))  # out的形状为 (batch_size, 1, hidden_size)

        # 只取最后一个时间步的输出
        out = out[:, -1, :]  # 形状为 (batch_size, hidden_size)

        # 全连接层映射到输出维度
        out = self.fc(out)  # 形状为 (batch_size, output_size)

        return out

def train_lstm(lr=0.001,epochs=150, weight_decay=1e-4, seed=0, metric='rmse', device='cpu'):
    """function for train"""
    setup_seed(seed)
    print("training seed "+str(seed)+':\n')
    train_loader, val_loader, test_35_data, test_36_data, test_37_data=get_data()
    test_data=[test_35_data, test_36_data, test_37_data]
    model = LSTMNetwork()
    model=model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.MSELoss()
    len_dataloader = len(train_loader)
    test_results=[]
    """早停止获取最佳模型"""
    val_mse=10
    for epoch in range(epochs):
        loss_epoch=0
        for X,y in train_loader:
            X,y = X.to(device), y.to(device)
            y_pred= model(X)
            y_pred = y_pred.squeeze(1)
            loss = criterion(y_pred,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_epoch += loss
        if (epoch+1)%5==0 and epoch!=0:
            print('Epoch:',epoch+1,'Train_RMSELoss:',loss_epoch/len_dataloader,'\n')
        if (epoch+1)%5==0 and epoch!=0:
            val_loss=0
            for val_x,val_y in val_loader:
                val_x,val_y=val_x.to(device),val_y.to(device)
                pre=model(val_x)
                val_loss+=criterion(pre.squeeze(1),val_y).detach()    
            print('Epoch:',epoch+1,'valid_RMSELoss:',val_loss/len(val_loader),'\n')
            val_mse=val_loss/len(val_loader)
                
        if (val_mse<5e-5 and epoch>=10)or (epoch+1)==epochs:
            model=model.cpu()
            for name in test_data:
                X=torch.from_numpy(name[0]).float()
                y=name[1]
                y_pred=model(X)
                y_pred= y_pred.squeeze(0).detach().numpy()
                test_results.append([y,y_pred])
            break
    return test_results
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
tests_lstm=[]
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
for i in range(5):
    test_result=train_lstm(seed=i,device=device)
    tests_lstm.append(test_result)
# Out:
# training seed 0:
#
# Epoch: 5 Train_RMSELoss: tensor(0.5487, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0446, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0108, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0090, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0048, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0026, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0017, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# training seed 1:
#
# Epoch: 5 Train_RMSELoss: tensor(0.8150, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0215, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0146, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0101, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0061, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0051, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0023, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# training seed 2:
#
# Epoch: 5 Train_RMSELoss: tensor(0.8730, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0271, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0131, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0094, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0042, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0016, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0004, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0003, device='cuda:0')
#
# training seed 3:
#
# Epoch: 5 Train_RMSELoss: tensor(0.4280, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.1471, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0134, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0100, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0063, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0042, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0031, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0024, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0018, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0009, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0008, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0007, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0006, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0005, device='cuda:0')
#
# training seed 4:
#
# Epoch: 5 Train_RMSELoss: tensor(0.6499, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 5 valid_RMSELoss: tensor(0.0251, device='cuda:0')
#
# Epoch: 10 Train_RMSELoss: tensor(0.0092, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 10 valid_RMSELoss: tensor(0.0113, device='cuda:0')
#
# Epoch: 15 Train_RMSELoss: tensor(0.0060, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 15 valid_RMSELoss: tensor(0.0066, device='cuda:0')
#
# Epoch: 20 Train_RMSELoss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 20 valid_RMSELoss: tensor(0.0047, device='cuda:0')
#
# Epoch: 25 Train_RMSELoss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 25 valid_RMSELoss: tensor(0.0037, device='cuda:0')
#
# Epoch: 30 Train_RMSELoss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 30 valid_RMSELoss: tensor(0.0028, device='cuda:0')
#
# Epoch: 35 Train_RMSELoss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 35 valid_RMSELoss: tensor(0.0021, device='cuda:0')
#
# Epoch: 40 Train_RMSELoss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 40 valid_RMSELoss: tensor(0.0018, device='cuda:0')
#
# Epoch: 45 Train_RMSELoss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 45 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 50 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 50 valid_RMSELoss: tensor(0.0015, device='cuda:0')
#
# Epoch: 55 Train_RMSELoss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 55 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 60 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 60 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 65 Train_RMSELoss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 65 valid_RMSELoss: tensor(0.0014, device='cuda:0')
#
# Epoch: 70 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 70 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 75 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 75 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 80 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 80 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 85 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 85 valid_RMSELoss: tensor(0.0013, device='cuda:0')
#
# Epoch: 90 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 90 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 95 Train_RMSELoss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 95 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 100 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 100 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 105 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 105 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 110 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 110 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 115 Train_RMSELoss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 115 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 120 Train_RMSELoss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 120 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 125 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 125 valid_RMSELoss: tensor(0.0010, device='cuda:0')
#
# Epoch: 130 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 130 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 135 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 135 valid_RMSELoss: tensor(0.0012, device='cuda:0')
#
# Epoch: 140 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 140 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 145 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 145 valid_RMSELoss: tensor(0.0011, device='cuda:0')
#
# Epoch: 150 Train_RMSELoss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
#
# Epoch: 150 valid_RMSELoss: tensor(0.0010, device='cuda:0')

# %%
rmse_all=[]
mae_all=[]
mape_all=[]
r2=[]
num=0
test_csv_l=[]
real_csv_l=[]
for i in range(4):
    for j in range(len(tests_lstm[0])):
        real,pred=tests_lstm[i][j][0],tests_lstm[i][j][1].reshape(-1)
        rmse=evaluation(real,pred)
        if rmse>=0.0:
            rmse_all.append(rmse)
            for pre,rea in zip(pred,real):
                test_csv_l.append(pre)
                real_csv_l.append(rea)
        mae_all.append(calculate_mae(real,pred))
        mape_all.append(mape(real,pred))
        r2.append(r_squared(real,pred))
        num+=1
print("RMSE:",rmse_all)
print("test:",test_csv_l)
print('real:',real_csv_l)
len(test_csv_l)
# Out:
# RMSE: [0.020863119961708153, 0.023464395405537446, 0.022466599726453425, 0.02449262617976955, 0.02644633221682224, 0.023341887835378557, 0.01599801482030712, 0.018159587403834453, 0.017010776116373263, 0.021793015922070516, 0.024665438819162278, 0.023181150519492464]
# test: [1.7888083, 1.8271024, 1.8562379, 1.8785905, 1.895926, 1.9095265, 1.9203182, 1.9289727, 1.9362901, 1.9423839, 1.9477098, 1.9515997, 1.9549521, 1.9578438, 1.9599328, 1.961719, 1.9631606, 1.9646808, 1.9661242, 1.9667281, 1.9676559, 1.9684329, 1.9688872, 1.9691597, 1.9693255, 1.9694136, 1.9694494, 1.9696933, 1.9697137, 1.9696279, 1.9692261, 1.9693453, 1.9693124, 1.9689419, 1.9690924, 1.9689779, 1.9687201, 1.9686627, 1.9682217, 1.9678943, 1.9676476, 1.9674096, 1.9672155, 1.9670645, 1.9668982, 1.966481, 1.96611, 1.9657853, 1.9653519, 1.9648833, 1.9646082, 1.9640882, 1.9636481, 1.9631441, 1.9629027, 1.9623389, 1.9620585, 1.9615033, 1.9610231, 1.9605896, 1.9602125, 1.9594467, 1.9588735, 1.9586165, 1.9578788, 1.9573395, 1.9568775, 1.9562436, 1.9556332, 1.9553992, 1.9548779, 1.9541386, 1.9532323, 1.9527711, 1.9519161, 1.9512203, 1.9510155, 1.9505373, 1.9501418, 1.9496145, 1.9489901, 1.9480854, 1.9474632, 1.9465426, 1.9455228, 1.9448725, 1.9442899, 1.9434925, 1.9431337, 1.9422551, 1.9413657, 1.9408079, 1.9399844, 1.9390703, 1.9378772, 1.93682, 1.9357731, 1.9350803, 1.9343588, 1.9333866, 1.9330506, 1.9322431, 1.9313356, 1.9306078, 1.9299653, 1.929152, 1.9282247, 1.9273473, 1.9267218, 1.9262893, 1.9253699, 1.9244097, 1.9236395, 1.9227461, 1.9219837, 1.9211434, 1.9200203, 1.919611, 1.9185356, 1.9178492, 1.9170464, 1.9160122, 1.914793, 1.9135048, 1.9125395, 1.9108071, 1.9096961, 1.9087925, 1.9080149, 1.9070678, 1.9061029, 1.9048635, 1.9035784, 1.9025571, 1.9010855, 1.9003162, 1.8990467, 1.8978713, 1.8967229, 1.89558, 1.895179, 1.8937241, 1.8926346, 1.8911604, 1.889478, 1.8880836, 1.8863094, 1.8846613, 1.8836088, 1.8822446, 1.8811159, 1.8800856, 1.8784871, 1.8766937, 1.8747803, 1.8707356, 1.8688933, 1.8678107, 1.8628054, 1.8618386, 1.8593383, 1.8569252, 1.8550514, 1.8537228, 1.8524272, 1.8508967, 1.8492271, 1.8476554, 1.8466026, 1.8443313, 1.8423716, 1.8401339, 1.8389368, 1.8378267, 1.8366506, 1.8333035, 1.8324711, 1.8295842, 1.8284798, 1.8265197, 1.8251632, 1.8239448, 1.8226184, 1.8209879, 1.8202865, 1.8188369, 1.817375, 1.8154311, 1.8140081, 1.8125795, 1.8107105, 1.8098524, 1.809037, 1.8072052, 1.8068255, 1.8057516, 1.8036635, 1.8025615, 1.8002785, 1.7995118, 1.7966521, 1.7953149, 1.7940423, 1.7929186, 1.7930491, 1.7920816, 1.7908212, 1.7898787, 1.7894232, 1.7897091, 1.7876227, 1.786394, 1.7853911, 1.7841642, 1.7832725, 1.7823215, 1.7806315, 1.7778789, 1.7759204, 1.7745185, 1.7726461, 1.7717721, 1.7712791, 1.7692258, 1.7682011, 1.7667181, 1.7647437, 1.7622843, 1.7597655, 1.7591068, 1.7572883, 1.7545836, 1.7521921, 1.7516906, 1.7516732, 1.7506545, 1.7491658, 1.7484292, 1.7470694, 1.7453253, 1.7433119, 1.7418797, 1.7406195, 1.7390866, 1.7374561, 1.7365435, 1.7338426, 1.7322934, 1.7318498, 1.7307706, 1.7302074, 1.7292571, 1.7281413, 1.727192, 1.7261329, 1.7249866, 1.7236668, 1.7223086, 1.7216446, 1.7203108, 1.7190619, 1.7207003, 1.7201108, 1.7187198, 1.7176886, 1.7163332, 1.7933623, 1.8306298, 1.8590084, 1.8808057, 1.8977324, 1.9110291, 1.9215922, 1.9300731, 1.937058, 1.9428715, 1.947455, 1.9513539, 1.9546027, 1.957365, 1.9597305, 1.9621112, 1.9637449, 1.9649116, 1.9658859, 1.9670156, 1.9670423, 1.9675913, 1.9683714, 1.9685699, 1.9690746, 1.969413, 1.9695864, 1.969607, 1.9695638, 1.9692365, 1.9690087, 1.9690533, 1.9688795, 1.9688566, 1.9686214, 1.9686174, 1.9679627, 1.9679729, 1.9677637, 1.9673305, 1.9671763, 1.9668257, 1.9665849, 1.9662457, 1.9660761, 1.9654104, 1.9650887, 1.9647535, 1.9644746, 1.9637591, 1.9632308, 1.9627047, 1.9623749, 1.9619583, 1.9616843, 1.9615488, 1.9609519, 1.9603317, 1.959544, 1.959235, 1.9585962, 1.9582181, 1.9573736, 1.9570118, 1.9565027, 1.9561559, 1.9555683, 1.9548706, 1.9540668, 1.9533801, 1.9522687, 1.9517064, 1.951032, 1.9507709, 1.9501277, 1.9496281, 1.9487503, 1.947865, 1.9474667, 1.9469041, 1.9464245, 1.9458119, 1.9449412, 1.943919, 1.9436027, 1.9430968, 1.9421803, 1.9414635, 1.940264, 1.9394543, 1.9384909, 1.9377884, 1.9366943, 1.9360596, 1.9355997, 1.9347234, 1.9337876, 1.9326534, 1.9319879, 1.93103 ...
# real: [1.963, 1.962, 1.962, 1.961, 1.96, 1.96, 1.965, 1.966, 1.965, 1.964, 1.965, 1.964, 1.963, 1.963, 1.963, 1.962, 1.962, 1.96, 1.962, 1.966, 1.962, 1.961, 1.959, 1.958, 1.957, 1.957, 1.956, 1.957, 1.958, 1.956, 1.955, 1.952, 1.952, 1.951, 1.955, 1.957, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.953, 1.952, 1.951, 1.953, 1.956, 1.955, 1.956, 1.955, 1.955, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.952, 1.953, 1.952, 1.952, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.948, 1.955, 1.956, 1.956, 1.953, 1.952, 1.951, 1.95, 1.949, 1.948, 1.948, 1.947, 1.947, 1.947, 1.945, 1.945, 1.944, 1.943, 1.943, 1.942, 1.941, 1.94, 1.94, 1.939, 1.939, 1.938, 1.938, 1.937, 1.937, 1.936, 1.935, 1.935, 1.934, 1.933, 1.933, 1.933, 1.932, 1.932, 1.931, 1.931, 1.93, 1.929, 1.929, 1.926, 1.925, 1.924, 1.923, 1.922, 1.921, 1.92, 1.919, 1.918, 1.915, 1.914, 1.912, 1.911, 1.908, 1.907, 1.906, 1.904, 1.902, 1.9, 1.899, 1.897, 1.895, 1.893, 1.892, 1.89, 1.889, 1.886, 1.884, 1.883, 1.881, 1.88, 1.878, 1.876, 1.875, 1.874, 1.872, 1.871, 1.87, 1.863, 1.861, 1.86, 1.855, 1.855, 1.853, 1.852, 1.851, 1.849, 1.848, 1.846, 1.845, 1.844, 1.843, 1.842, 1.843, 1.843, 1.842, 1.839, 1.837, 1.836, 1.834, 1.832, 1.835, 1.834, 1.833, 1.832, 1.831, 1.829, 1.822, 1.82, 1.818, 1.816, 1.821, 1.822, 1.821, 1.818, 1.816, 1.818, 1.818, 1.816, 1.808, 1.805, 1.804, 1.808, 1.808, 1.807, 1.804, 1.803, 1.802, 1.801, 1.799, 1.798, 1.796, 1.795, 1.794, 1.794, 1.794, 1.791, 1.79, 1.787, 1.784, 1.783, 1.781, 1.779, 1.777, 1.775, 1.773, 1.772, 1.77, 1.769, 1.768, 1.766, 1.765, 1.765, 1.764, 1.756, 1.754, 1.751, 1.75, 1.748, 1.749, 1.749, 1.745, 1.745, 1.743, 1.739, 1.736, 1.734, 1.732, 1.729, 1.727, 1.723, 1.721, 1.719, 1.715, 1.714, 1.711, 1.709, 1.707, 1.704, 1.701, 1.702, 1.703, 1.702, 1.699, 1.68, 1.678, 1.675, 1.674, 1.676, 1.967, 1.965, 1.965, 1.964, 1.964, 1.963, 1.965, 1.968, 1.969, 1.968, 1.968, 1.968, 1.967, 1.966, 1.966, 1.966, 1.965, 1.964, 1.965, 1.965, 1.969, 1.966, 1.965, 1.964, 1.963, 1.962, 1.962, 1.961, 1.961, 1.96, 1.961, 1.96, 1.961, 1.961, 1.96, 1.96, 1.959, 1.957, 1.956, 1.956, 1.958, 1.959, 1.959, 1.958, 1.959, 1.958, 1.957, 1.956, 1.955, 1.955, 1.954, 1.953, 1.955, 1.957, 1.957, 1.957, 1.956, 1.956, 1.955, 1.954, 1.954, 1.953, 1.953, 1.952, 1.952, 1.952, 1.952, 1.951, 1.951, 1.949, 1.947, 1.947, 1.947, 1.949, 1.95, 1.949, 1.948, 1.947, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.942, 1.946, 1.949, 1.95, 1.949, 1.948, 1.947, 1.946, 1.945, 1.944, 1.943, 1.942, 1.943, 1.942, 1.942, 1.941, 1.939, 1.938, 1.938, 1.937, 1.936, 1.935, 1.934, 1.933, 1.933, 1.932, 1.932, 1.931, 1.93, 1.93, 1.929, 1.928, 1.928, 1.927, 1.927, 1.926, 1.926, 1.925, 1.925, 1.924, 1.924, 1.923, 1.923, 1.922, 1.921, 1.919, 1.918, 1.918, 1.916, 1.915, 1.914, 1.913, 1.912, 1.911, 1.91, 1.91, 1.909, 1.908, 1.907, 1.905, 1.904, 1.903, 1.902, 1.901, 1.899, 1.898, 1.896, 1.895, 1.891, 1.89, 1.889, 1.887, 1.885, 1.884, 1.882, 1.88, 1.878, 1.877, 1.876, 1.875, 1.873, 1.872, 1.871, 1.863, 1.86, 1.859, 1.862, 1.86, 1.86, 1.864, 1.863, 1.863, 1.863, 1.861, 1.86, 1.858, 1.858, 1.85, 1.848, 1.849, 1.848, 1.848, 1.848, 1.845, 1.844, 1.842, 1.841, 1.84, 1.841, 1.841, 1.84, 1.839, 1.835, 1.833, 1.831, 1.829, 1.827, 1.825, 1.823, 1.824, 1.825, 1.824, 1.822, 1.819, 1.82, 1.82, 1.818, 1.812, 1.81, 1.807, 1.806, 1.807, 1.808, 1.807, 1.804, 1.803, 1.799, 1.799, 1.798, 1.794, 1.791, 1.79, 1.788, 1.785, 1.782, 1.78, 1.776, 1.774, 1.771, 1.769, 1.766, 1.762, 1.759, 1.756, 1.755, 1.752, 1.749, 1.747, 1.746, 1.745, 1.741, 1.739, 1.735, 1.736, 1.733, 1.726, 1.726, 1.724, 1.721, 1.72, 1.718, 1.717, 1.717, 1.714, 1.712, 1.709, 1.708, 1.704, 1.703, 1.701, 1.7, 1.964, 1.962, 1.961, 1.961, 1.961, 1.96, 1.963, 1.965, 1.966, 1.965, 1.965, 1.964, 1.963, 1.963, 1.962, 1.961, 1.961, 1.962, 1.966, 1.963, 1.959, 1.959, 1.958, 1.958, 1.958, 1.958, 1.958, 1.959, 1.958, 1.957, 1.957, 1.954, 1.953, 1.952, 1.954, 1.956, 1.957, 1.956, 1.956, 1.956, 1.955, 1.954, 1.953, 1.953, 1.952, 1.954, 1. ...
# 6480

# %%
import pandas as pd
data={
    'prop pred':test_csv_p,
    'prop real':real_csv_p,
    'mlp pred': test_csv_m,
    'mlp real':real_csv_m,
    'cnn pred': test_csv_c,
    'cnn real':real_csv_c,
    'lstm pred':test_csv_l,
    'lstm real':real_csv_l,
}
df=pd.DataFrame(data)
print(df)
df.to_csv('../csv_results/xjtu.csv',index=False)
# Out:
#       prop pred  prop real  mlp pred  mlp real  cnn pred  cnn real  lstm pred  \
# 0      1.952691      1.963  1.978342     1.963  1.930529     1.963   1.788808
# 1      1.953426      1.962  1.993036     1.962  1.939135     1.962   1.827102
# 2      1.954059      1.962  2.007612     1.962  1.941721     1.962   1.856238
# 3      1.954617      1.961  2.013209     1.961  1.941426     1.961   1.878590
# 4      1.955176      1.960  2.005258     1.960  1.941626     1.960   1.895926
# ...         ...        ...       ...       ...       ...       ...        ...
# 6475   1.674112      1.647  1.892118     1.647  1.647983     1.647   1.697512
# 6476   1.673858      1.644  1.897010     1.644  1.647284     1.644   1.697008
# 6477   1.673604      1.640  1.901566     1.640  1.649709     1.640   1.696495
# 6478   1.673352      1.637  1.905347     1.637  1.652977     1.637   1.695826
# 6479   1.673102      1.636  1.913125     1.636  1.651022     1.636   1.695920
#
#       lstm real
# 0         1.963
# 1         1.962
# 2         1.962
# 3         1.961
# 4         1.960
# ...         ...
# 6475      1.647
# 6476      1.644
# 6477      1.640
# 6478      1.637
# 6479      1.636
#
# [6480 rows x 8 columns]

# %%
rmse_all=0
mae_all=0
num=0
for i in range(len(tests_cnn)):
    for j in range(len(tests_cnn[0])):
        real,pred=tests_cnn[i][j][0],tests_cnn[i][j][1]
        rmse=evaluation(real,pred)
        rmse_all+=(rmse)
        mae_all+=calculate_mae(real,pred)
        num+=1
print('RMSE:',[rmse_all/num])
print('MAE:',mae_all/num)
# Out:
# RMSE: [0.04988660577758232]
# MAE: [0.03999891]
